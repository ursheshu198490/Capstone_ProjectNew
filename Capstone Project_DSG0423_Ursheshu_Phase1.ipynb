# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.amazon.in/")

# %%
#Enter designation in search box
designation = driver.find_element(By.XPATH, "/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
designation.send_keys('Men Clothing')

# %%
search = driver.find_element(By.XPATH, '/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %%
allen = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/div/a/i')
allen.click()

# %%
birthday = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/div/div/ul/li/span/div/div/ul/span[4]/li/span/a/div/label/i')
birthday.click()

# %%
osc = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[7]/div[12]/a/i')
osc.click()

# %%
birthdaynew = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[7]/div[12]/div/ul/span[3]/li/span/a/div/label/i')
osc.click()

# %%
##Creating Empty List for different attributes-
brand_name = []
brand_tags = driver.find_elements(By.XPATH, '//span[@class="a-size-base-plus a-color-base"]')
for i in brand_tags:
    brand=i.text
    brand_name.append(brand)

# %%
len(brand_name)
# Out:
# 48

# %%
brand_name
# Out:
# ['Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly',
#  'Allen Solly']

# %%
##Creating Empty List for different attributes-
product_name = []
product_tags = driver.find_elements(By.XPATH, '//span[@class="a-size-base-plus a-color-base a-text-normal"]')
for i in product_tags:
    product=i.text
    product_name.append(product)

# %%
len(product_name)
# Out:
# 48

# %%
product_name
# Out:
# ["Men's Regular Fit Polo",
#  "Men's Regular Fit T-Shirt",
#  'Men T-Shirt',
#  "Men's Regular Fit Polo",
#  'Men Sweatshirt',
#  'Men Sweatshirt',
#  "Men's Shirt",
#  "Men's Polyester Standard Length Casual Jacket",
#  "Men's Cotton Crew Neck Sweatshirt",
#  "Men's T-Shirt",
#  "Men's Polo",
#  "Men's Shirt",
#  "Men's Shirt",
#  'Men Belt',
#  "Men's Shirt",
#  "Men's Shirt",
#  "Men's T-Shirt",
#  "Men's Shirt",
#  "Men's Regular Fit T-Shirt",
#  "Men's Shirt",
#  "Men's Regular Fit T-Shirt",
#  "Men's Shirt",
#  "Men's Shirt",
#  "Men's Shirt",
#  "Men's Shirt",
#  'Men Casual Pants',
#  "Men's Shirt",
#  'Men Jeans',
#  'Men Jeans',
#  "Men's Slim Casual Pants (ASTFQSRFH41658_Cream",
#  'Men Business Suit Pants Set',
#  'Men Regular Track Pants',
#  "Men's T-Shirt",
#  "Men's Shirt",
#  "Men's Polyester Blend Three Piece Suit-Dress Set (ASS3SSLFL60388_Brown_38",
#  "Men's Cotton High Neck Casual Zipper Sweatshirt",
#  "Men's Regular Fit Track Pants",
# ...

# %%
##Creating Empty List for different attributes-
price_value = []
price_tags = driver.find_elements(By.XPATH, '//span[@class="a-price-whole"]')
for i in price_tags:
    price=i.text
    price_value.append(price)

# %%
len(price_value)
# Out:
# 48

# %%
price_value
# Out:
# ['699',
#  '759',
#  '462',
#  '699',
#  '1,189',
#  '769',
#  '1,299',
#  '1,429',
#  '824',
#  '909',
#  '679',
#  '1,126',
#  '1,494',
#  '842',
#  '1,201',
#  '1,136',
#  '1,999',
#  '1,299',
#  '2,399',
#  '2,299',
#  '1,079',
#  '1,494',
#  '1,331',
#  '1,331',
#  '2,799',
#  '1,299',
#  '1,264',
#  '2,999',
#  '2,449',
#  '1,624',
#  '9,999',
#  '989',
#  '1,599',
#  '2,499',
#  '17,999',
#  '1,484',
#  '815',
#  '369',
#  '2,499',
#  '1,799',
#  '1,609',
#  '1,526',
#  '1,494',
#  '1,299',
#  '879',
#  '1,429',
#  '909',
#  '2,349']

# %%
#fetching url to open each product
product_url = []
url = driver.find_elements(By.XPATH, '//a[@class="a-link-normal s-no-outline"]')
for i in url:
    product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 48

# %%
product_url
# Out:
# ['https://www.amazon.in/Allen-Solly-Regular-AMKP317G04249_Jet-Black_Large/dp/B06Y2FG6R7/ref=sr_1_1?crid=12Q9LERDEQPD5&dib=eyJ2IjoiMSJ9.GmVNw1D3_PT4yFoFmNQQxVhk8KEDBKNpG1xfb1uJhxoOXKl7skBdVP5yWKUlllGhCiIQMo4wMQo4MDIxHiqNTWXx6CBnaQR530-9Y7h6tlSB3yAAGTjhYzc6l9uX9U4jXAlY-0IWiEPTVnFtz0jfFI9JN5UBkIbkp5ozffkeh0gqxr64dpEnmHTdCt3e2eGJF4Uwp9AL4La0LgDGL67MUfjQf6CG5iUnJKGqejw9_1T0GTmpVh0QKrOeV_0M1jTxUosQYyZmXEFrXqf9PPKaq5C-7YvogpJkm3pGBrfqtIY.9GWvnVcXNERbqZB-ieu1vX0E8IUTzHsWcp2Ma9j-31s&dib_tag=se&keywords=Men+Clothing&qid=1713063982&refinements=p_123%3A398346&rnid=91049095031&s=apparel&sprefix=m%2Caps%2C169&sr=1-1',
# ...

# %%
Sno = []          #Creating an empty list

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch full job details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div/div[14]/div[10]/div/div[1]/ul/li[4]/span/span[2]')
        Sno.append(description.text)
    except NoSuchElementException :
        Sno.append('Not present')

# %%
len(Sno)
# Out:
# 48

# %%
Sno
# Out:
# ['B06Y2FG6R7',
#  'B0C7ZNQ9Y7',
#  'Not present',
#  'Not present',
#  'Not present',
#  'B07ZT66BTB',
#  'B0CT3H6BH2',
#  'Not present',
#  'Not present',
#  'B0CSLFPS9B',
#  'Not present',
#  'Not present',
#  'B0CSKC8BSW',
#  'Not present',
#  'B0CSKD1NB3',
#  'B0CQ4LTXBM',
#  'B0CNGZNMZZ',
#  'B0CT3FQBWS',
#  'B0CNH2GQ3R',
#  'B0CW39GRLS',
#  'B0CNH2DBN5',
#  'B0CRF299PG',
#  'Not present',
#  'B0CQ4K548R',
#  'B0CQ4GTBK4',
#  'Not present',
#  'B0CNH3NSFX',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'B0CTQWKS2H',
#  'B0CTQWXDW1',
#  'Not present',
#  'B0BJDZQ6YL',
#  'Not present',
#  'Not present',
#  'B0CSKCV67J',
#  'B0CNY7C3J3',
#  'Not present',
#  'B0CT3FVN1K',
#  'B0CTQVVRXL',
#  'Not present',
#  'Not present',
#  'Not present',
#  'B0CSLGHSSZ',
#  'B0CSKCS3XT']

# %%
product_code = []          #Creating an empty list

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch full job details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div/div[14]/div[10]/div/div[1]/ul/li[5]/span/span[2]')
        product_code.append(description.text)
    except NoSuchElementException :
        product_code.append('Not present')

# %%
len(product_code)
# Out:
# 48

# %%
product_code
# Out:
# ['Not present',
#  'ASKCCURGF354483',
#  'ALKCVSGFS94817',
#  'Not present',
#  'Not present',
#  'ASSTLRGF389900',
#  'ASSFQSPBH19367',
#  'Not present',
#  'Not present',
#  'ASKPCURGBM04184',
#  'Not present',
#  'Not present',
#  'ASSFQSPBH05664',
#  'Not present',
#  'ASSFQSPFO85820',
#  'ASSFQSPF559101',
#  'ASKPMRGFK38027',
#  'ASSFQSPPF54813',
#  'ASKPORRGF311623',
#  'ALSFVCUFE81122_Multi_40',
#  'ASKWQRGFF75484',
#  'ASSFQSPBW75454',
#  'Not present',
#  'ASSFQSPFQ20158',
#  'ASSFCUSPFV07307',
#  'Not present',
#  'ASSFQSPFE13742',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'ASKWQRGFJ22307',
#  'ASSFQSPBZ18945',
#  'Not present',
#  'ASSTFORGFL71220',
#  'Not present',
#  'Not present',
#  'ALSFACUBC50314',
#  'ALKPARGFI73968',
#  'Not present',
#  'ASSFQSPP821933',
#  'ASSFQSPBQ29879',
#  'Not present',
#  'Not present',
#  'Not present',
#  'ALKCVSGF032887',
#  'ALSFVCUFM52051']

# %%
category_name = []          #Creating an empty list

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch full job details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div/div[14]/div[10]/div/div[1]/ul/li[7]/span/span[2]')
        category_name.append(description.text)
    except NoSuchElementException :
        category_name.append('Not present')

# %%
len(category_name)
# Out:
# 48

# %%
category_name
# Out:
# ['Not present',
#  'Men',
#  'Men',
#  'Not present',
#  'Not present',
#  'Men',
#  'Men',
#  'Not present',
#  'Not present',
#  'Men',
#  'Not present',
#  'Not present',
#  'Men',
#  'Not present',
#  'Men',
#  'Men',
#  'Men',
#  'Men',
#  'Men',
#  'Men',
#  'Men',
#  'Men',
#  'Not present',
#  'Men',
#  'Men',
#  'Not present',
#  'Men',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Men',
#  'Men',
#  'Not present',
#  'Men',
#  'Not present',
#  'Not present',
#  'Men',
#  'Men',
#  'Not present',
#  'Men',
#  'Men',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Men',
#  'Men']

# %%
# Creating Dataframe-
Table1new_1=pd.DataFrame({'Sno':Sno,'Brandname':brand_name,'Category':category_name, 'Producttype':product_name,
                       'Productcode': product_code, 'Price': price_value})
Table1new_1
# Out:
#             Sno    Brandname     Category  \
# 0    B06Y2FG6R7  Allen Solly  Not present
# 1    B0C7ZNQ9Y7  Allen Solly          Men
# 2   Not present  Allen Solly          Men
# 3   Not present  Allen Solly  Not present
# 4   Not present  Allen Solly  Not present
# 5    B07ZT66BTB  Allen Solly          Men
# 6    B0CT3H6BH2  Allen Solly          Men
# 7   Not present  Allen Solly  Not present
# 8   Not present  Allen Solly  Not present
# 9    B0CSLFPS9B  Allen Solly          Men
# 10  Not present  Allen Solly  Not present
# 11  Not present  Allen Solly  Not present
# 12   B0CSKC8BSW  Allen Solly          Men
# 13  Not present  Allen Solly  Not present
# 14   B0CSKD1NB3  Allen Solly          Men
# 15   B0CQ4LTXBM  Allen Solly          Men
# 16   B0CNGZNMZZ  Allen Solly          Men
# 17   B0CT3FQBWS  Allen Solly          Men
# 18   B0CNH2GQ3R  Allen Solly          Men
# 19   B0CW39GRLS  Allen Solly          Men
# 20   B0CNH2DBN5  Allen Solly          Men
# ...

# %%
Table1new_1.to_csv('table1.1_copy.csv')

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.amazon.in/")

# %%
#Enter designation in search box
designation = driver.find_element(By.XPATH, "/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
designation.send_keys('Men Clothing')

# %%
search = driver.find_element(By.XPATH, '/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %%
brand = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/div/a/i')
brand.click()

# %%
more = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div/div/div/div[5]/div/a/i')
more.click()

# %%
allen = driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div/div/div/div[5]/div/div/ul/li/span/div/div/ul/span[7]/li/span/a/div/label/i')
allen.click()

# %%
osc= driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div/div/div/div[7]/div[12]/a/i')
osc.click()

# %%
birthday=driver.find_element(By.XPATH, '/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div/div/div/div[7]/div[12]/div/ul/span[2]/li/span/a/div/label/i')
birthday.click()

# %%
#fetching url to open each product
product_url = []
url = driver.find_elements(By.XPATH, '//a[@class="a-link-normal s-no-outline"]')
for i in url:
    product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 36

# %%
Sno = []          #Creating an empty list

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch full job details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div/div[14]/div[10]/div/div[1]/ul/li[4]/span/span[2]')
        Sno.append(description.text)
    except NoSuchElementException :
        Sno.append('Not present')

# %%
Sno
# Out:
# ['Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'B0BCGLKC59',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present']

# %%
color_1 = []          #Creating an empty list

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch full job details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div/div[7]/div[1]/div[2]/div[2]/div/div/div[1]/div[24]/div[1]/div/form/div[1]/div/span')
        color_1.append(description.text)
    except NoSuchElementException :
        color_1.append('Not present')

# %%
color_1
# Out:
# ['Not present',
#  'Light Blue',
#  'Navy',
#  'Navy',
#  'Olive',
#  'Multicolour',
#  'Navy',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Olive',
#  'Not present',
#  'Yellow',
#  'Brown',
#  'Medium Blue',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Multicolour',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Maroon',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Light Yellow',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present']

# %%
wear_type = []          #Creating an empty list

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch full job details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div/div[14]/div[10]/div/div[1]/ul/li[12]/span/span[2]')
        wear_type.append(description.text)
    except NoSuchElementException :
        wear_type.append('Not present')

# %%
len(wear_type)
# Out:
# 36

# %%
wear_type
# Out:
# ['Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  '28 x 27 x 2 Centimeters',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present']

# %%
material_type = []          #Creating an empty list

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch full job details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div/div[7]/div[1]/div[2]/div[2]/div/div/div[1]/div[32]/div/div[1]/div[1]/div/div[2]/span/span')
        material_type.append(description.text)
    except NoSuchElementException :
        material_type.append('Not present')

# %%
material_type
# Out:
# ['100% Cotton',
#  '100% Cotton',
#  '98% Cotton, 2% Spandex',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '98% Cotton, 2% Spandex',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '60% Cotton, 40% Polyester',
#  '60% Cotton, 40% Polyester',
#  '60% Cotton, 40% Polyester',
#  '60% Cotton, 40% Polyester',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100% Cotton',
#  '100%Cotton',
#  '85% Cotton and 15% Linen']

# %%
reviews_type = []          #Creating an empty list

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch full job details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div/div[7]/div[1]/div[2]/div[2]/div/div/div[1]/div[1]/div[2]/div[4]/div/span[3]/a/span')
        reviews_type.append(description.text)
    except NoSuchElementException :
        reviews_type.append('Not present')

# %%
reviews_type
# Out:
# ['66 ratings',
#  'Not present',
#  '3 ratings',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  '41 ratings',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  '56 ratings',
#  '58 ratings',
#  '3 ratings',
#  '66 ratings',
#  '255 ratings',
#  '73 ratings',
#  '44 ratings',
#  'Not present',
#  'Not present',
#  '79 ratings',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present']

# %%
# Creating Dataframe-
Table2_1=pd.DataFrame({'Sno':Sno,'color1':color_1,'color2':color_1, 'color3':color_1, 'color4':color_1,
                       'Weartype': wear_type, 'Material type':material_type, 'reviews': reviews_type})
Table2_1
# Out:
#             Sno        color1        color2        color3        color4  \
# 0   Not present   Not present   Not present   Not present   Not present
# 1   Not present    Light Blue    Light Blue    Light Blue    Light Blue
# 2   Not present          Navy          Navy          Navy          Navy
# 3   Not present          Navy          Navy          Navy          Navy
# 4   Not present         Olive         Olive         Olive         Olive
# 5   Not present   Multicolour   Multicolour   Multicolour   Multicolour
# 6   Not present          Navy          Navy          Navy          Navy
# 7   Not present   Not present   Not present   Not present   Not present
# 8   Not present   Not present   Not present   Not present   Not present
# 9   Not present   Not present   Not present   Not present   Not present
# 10  Not present         Olive         Olive         Olive         Olive
# 11  Not present   Not present   Not present   Not present   Not present
# ...

# %%
Table2_1.to_csv('table2.1_copy.csv')

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-current slick-active"]')
subcategory_analyst.click()

# %%
#Creating Empty List for different attributes-
product_name = []
start=0
end=6
for page in range(start,end):
    product_tags = driver.find_elements(By.XPATH, '//div[@class="title-wish"]/a')
    for i in product_tags:
        product=i.text
        product_name.append(product)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[7]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')

# %%
len(product_name)
# Out:
# 288

# %%
product_name
# Out:
# ['Men Navy Blue Printed Round Neck Half...',
#  'Men White Printed T-Shirt',
#  'Men Rust Orange Printed T-Shirt',
#  'Men Yellow Printed T-Shirt',
#  'Men Red Printed T-Shirt',
#  'Men NAvy Blue Printed T-Shirt',
#  'Men White Printed T-Shirt',
#  'Men Olive Printed T-Shirt',
#  'Men NAvy Blue Printed T-Shirt',
#  'Men Grey Printed T-Shirt',
#  'Men Blue Printed T-Shirt',
#  'Men Blue Printed T-Shirt',
#  'Men Blue Jaquard T-Shirt',
#  'Men Sky Blue Plain T-Shirt',
#  'Men Beige Plain T-Shirt',
#  'Men Camel Brown Plain T-Shirt',
#  'Men Blue Printed T-Shirt',
#  'Men Sky Blue Printed T-Shirt',
#  'Men Green Printed T-Shirt',
#  'Men Blue Printed T-Shirt',
#  'Men White Printed T-Shirt',
#  'Men Black Printed T-Shirt',
#  'Men Black Printed T-Shirt',
#  'Men Olive Printed T-Shirt',
#  'Men Blue Printed T-Shirt',
#  'Men White Printed T-Shirt',
#  'Men Blue Printed T-Shirt',
#  'Men Pink Solid T-Shirt',
#  'Men NAvy Blue Printed T-Shirt',
#  'Men Green Self Design T-Shirt',
# ...

# %%
#fetching url to open each product
product_url = []
start=0
end=6
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[8]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')

# %%
len(product_url)
# Out:
# 288

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-navy-blue-printed-round-neck-half-sleeve-t-shirt-223062231-1',
#  'https://www.montecarlo.in/products/monte-carlo-men-white-printed-t-shirt-38647',
#  'https://www.montecarlo.in/products/monte-carlo-men-rust-orange-printed-t-shirt-38645',
#  'https://www.montecarlo.in/products/monte-carlo-men-yellow-printed-t-shirt-38644',
#  'https://www.montecarlo.in/products/monte-carlo-men-red-printed-t-shirt-38639',
#  'https://www.montecarlo.in/products/monte-carlo-men-navy-blue-printed-t-shirt-38638',
#  'https://www.montecarlo.in/products/monte-carlo-men-white-printed-t-shirt-38637',
#  'https://www.montecarlo.in/products/monte-carlo-men-olive-printed-t-shirt-38625',
#  'https://www.montecarlo.in/products/monte-carlo-men-navy-blue-printed-t-shirt-38624',
#  'https://www.montecarlo.in/products/monte-carlo-men-grey-printed-t-shirt-38623',
#  'https://www.montecarlo.in/products/monte-carlo-men-blue-printed-t-shirt-38615',
# ...

# %%
price_typenew = []          #Creating an empty list

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/product-meta/div/div[1]/span[1]')
        price_typenew.append(description.text)
    except NoSuchElementException :
        price_typenew.append('Not present')

# %%
len(price_typenew)
# Out:
# 288

# %%
price_typenew
# Out:
# ['Sale price\nRs. 885.00',
#  'Sale price\nRs. 807.00',
#  'Not present',
#  'Sale price\nRs. 807.00',
#  'Sale price\nRs. 894.00',
#  'Sale price\nRs. 864.00',
#  'Not present',
#  'Sale price\nRs. 1,020.00',
#  'Not present',
#  'Sale price\nRs. 927.00',
#  'Sale price\nRs. 987.00',
#  'Sale price\nRs. 1,044.00',
#  'Sale price\nRs. 987.00',
#  'Sale price\nRs. 1,070.00',
#  'Sale price\nRs. 1,070.00',
#  'Sale price\nRs. 1,042.00',
#  'Sale price\nRs. 774.00',
#  'Sale price\nRs. 864.00',
#  'Sale price\nRs. 927.00',
#  'Sale price\nRs. 1,042.00',
#  'Sale price\nRs. 1,042.00',
#  'Sale price\nRs. 1,020.00',
#  'Sale price\nRs. 644.00',
#  'Sale price\nRs. 662.00',
#  'Sale price\nRs. 864.00',
#  'Sale price\nRs. 927.00',
#  'Sale price\nRs. 864.00',
#  'Sale price\nRs. 837.00',
#  'Sale price\nRs. 1,122.00',
#  'Sale price\nRs. 1,017.00',
#  'Sale price\nRs. 1,017.00',
#  'Sale price\nRs. 1,017.00',
#  'Sale price\nRs. 1,042.00',
#  'Sale price\nRs. 809.00',
# ...

# %%
product_code = []          #Creating an empty list

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch product details
    time.sleep(5)          #taking each url one by one as an input
    try:
        key = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/div[3]/button[1]/span[2]/svg/g[3]/path')
        key.click()
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/p')
        product_code.append(description.text)
    except NoSuchElementException :
        product_code.append('Not present')

# %%
len(product_code)
# Out:
# 288

# %%
product_code
# Out:
# ['Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
# ...

# %%
# Creating Dataframe-
Monte1_1=pd.DataFrame({'ProductName':product_name, 'Price':price_typenew})
Monte1_1
# Out:
#                                   ProductName                   Price
# 0    Men Navy Blue Printed Round Neck Half...  Sale price\nRs. 885.00
# 1                   Men White Printed T-Shirt  Sale price\nRs. 807.00
# 2             Men Rust Orange Printed T-Shirt             Not present
# 3                  Men Yellow Printed T-Shirt  Sale price\nRs. 807.00
# 4                     Men Red Printed T-Shirt  Sale price\nRs. 894.00
# ..                                        ...                     ...
# 283                   Men Blue Stripe T-Shirt             Not present
# 284                     Men Red Solid T-Shirt  Sale price\nRs. 987.00
# 285                Men Yellow Printed T-Shirt  Sale price\nRs. 744.00
# 286                 Men Black Printed T-Shirt  Sale price\nRs. 807.00
# 287                 Men White Printed T-Shirt             Not present
#
# [288 rows x 2 columns]

# %%
Monte1_1.to_csv('monte1_1_copy.csv')

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-current slick-active"]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=6
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[8]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')

# %%
len(product_url)
# Out:
# 288

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-navy-blue-printed-round-neck-half-sleeve-t-shirt-223062231-1',
#  'https://www.montecarlo.in/products/monte-carlo-men-white-printed-t-shirt-38647',
#  'https://www.montecarlo.in/products/monte-carlo-men-rust-orange-printed-t-shirt-38645',
#  'https://www.montecarlo.in/products/monte-carlo-men-yellow-printed-t-shirt-38644',
#  'https://www.montecarlo.in/products/monte-carlo-men-red-printed-t-shirt-38639',
#  'https://www.montecarlo.in/products/monte-carlo-men-navy-blue-printed-t-shirt-38638',
#  'https://www.montecarlo.in/products/monte-carlo-men-white-printed-t-shirt-38637',
#  'https://www.montecarlo.in/products/monte-carlo-men-olive-printed-t-shirt-38625',
#  'https://www.montecarlo.in/products/monte-carlo-men-navy-blue-printed-t-shirt-38624',
#  'https://www.montecarlo.in/products/monte-carlo-men-grey-printed-t-shirt-38623',
#  'https://www.montecarlo.in/products/monte-carlo-men-blue-printed-t-shirt-38615',
# ...

# %%
#Creating Empty List for different attributes-
size_1=[]
size_2=[]
size_3=[]
size_4=[]

# %%
size_1=[]

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[1]/label')
        size_1.append(description.text)
    except NoSuchElementException :
        size_1.append('Not present')

# %%
len(size_1)
# Out:
# 288

# %%
size_1
# Out:
# ['36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  'Not present',
#  '36/S',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  'Not present',
#  '38/M',
#  'Not present',
#  '38/M',
#  'Not present',
#  '38/M',
#  '38/M',
#  'Not present',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  'Not present',
#  '38/M',
#  'Not present',
#  'Not present',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '36/S',
#  '36/S',
#  '36/S',
#  'Not present',
#  '36/S',
#  '36/S',
#  'Not present',
#  '36/S',
#  'Not present',
#  'Not present',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  '36/S',
#  'Not present',
#  'Not present',
#  '36/S',
#  '36/S',
#  'Not present',
#  '36/S',
#  '36/S',
#  '38/M',
#  'Not present',
#  '38/M',
#  'Not present',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  'Not present',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
# ...

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[2]/label')
        size_2.append(description.text)
    except NoSuchElementException :
        size_2.append('Not present')

# %%
len(size_2)
# Out:
# 288

# %% [markdown]
# size_2

# %%
size_2
# Out:
# ['38/M',
#  '38/M',
#  'Not present',
#  '38/M',
#  '38/M',
#  'Not present',
#  'Not present',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '40/L',
#  '40/L',
#  '40/L',
#  'Not present',
#  '40/L',
#  'Not present',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  'Not present',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '38/M',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  'Not present',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
#  '40/L',
# ...

# %%
size_3=[]
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[4]/label')
        size_3.append(description.text)
    except NoSuchElementException :
        size_3.append('Not present')

# %%
len(size_3)
# Out:
# 288

# %%
size_3
# Out:
# ['42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '44/XXL',
#  '44/XXL',
#  'Not present',
#  '44/XXL',
#  '44/XXL',
#  'Not present',
#  '44/XXL',
#  '44/XXL',
#  'Not present',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  'Not present',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  'Not present',
#  '42/XL',
#  'Not present',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  'Not present',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  'Not present',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  'Not present',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  'Not present',
#  '44/XXL',
#  '44/XXL',
# ...

# %%
# Creating Dataframe-
Montesize_1=pd.DataFrame({'size1':size_1, 'size2':size_2, 'size3': size_3})
Montesize_1
# Out:
#            size1        size2  size3
# 0           36/S         38/M  42/XL
# 1           36/S         38/M  42/XL
# 2           36/S  Not present  42/XL
# 3           36/S         38/M  42/XL
# 4           36/S         38/M  42/XL
# ..           ...          ...    ...
# 283  Not present         38/M  42/XL
# 284         36/S         38/M  42/XL
# 285         36/S         38/M  42/XL
# 286         36/S         38/M  42/XL
# 287  Not present         38/M  42/XL
#
# [288 rows x 3 columns]

# %%
Montesize_1.to_csv('montesize_1_copy.csv')

# %%
size_4=[]
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[4]/label')
        size_4.append(description.text)
    except NoSuchElementException :
        size_4.append('Not present')

# %%
len(size_4)
# Out:
# 288

# %%
size_4
# Out:
# ['42/XL',
#  'Not present',
#  '42/XL',
#  '42/XL',
#  'Not present',
#  'Not present',
#  '42/XL',
#  '42/XL',
#  'Not present',
#  '42/XL',
#  'Not present',
#  '42/XL',
#  'Not present',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  '42/XL',
#  'Not present',
#  '44/XXL',
#  '44/XXL',
#  'Not present',
#  'Not present',
#  '44/XXL',
#  'Not present',
#  '44/XXL',
#  'Not present',
#  'Not present',
#  '44/XXL',
#  '44/XXL',
#  'Not present',
#  'Not present',
#  '44/XXL',
#  'Not present',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  'Not present',
#  'Not present',
#  'Not present',
#  '44/XXL',
#  '44/XXL',
#  '44/XXL',
#  'Not present',
#  '42/XL',
#  '42/XL',
#  'Not present',
#  '42/XL',
#  '42/XL',
#  'Not present',
#  '42/XL',
#  'Not present',
#  'Not present',
#  'Not present',
#  '42/XL',
#  '42/XL',
#  'Not present',
#  'Not present',
#  'Not present',
#  '42/XL',
#  '42/XL',
#  'Not present',
#  '42/XL',
#  'Not present',
#  'Not present',
#  '42/XL',
#  '44/XXL',
#  '44/XXL',
# ...

# %%
# Creating Dataframe-
import pandas as pd
Montesize_2=pd.DataFrame({'size4':size_4})
Montesize_2
# Out:
#            size4
# 0          42/XL
# 1    Not present
# 2          42/XL
# 3          42/XL
# 4    Not present
# ..           ...
# 283        42/XL
# 284        42/XL
# 285  Not present
# 286        42/XL
# 287        42/XL
#
# [288 rows x 1 columns]

# %%
# Creating Dataframe-
import pandas as pd
Montesize_final=pd.DataFrame({'Size1':size_1, 'Size2':size_2, 'Size3': size_3, 'Size4':size_4})
Montesize_final
# Out:
#            Size1        Size2  Size3        Size4
# 0           36/S         38/M  42/XL        42/XL
# 1           36/S         38/M  42/XL  Not present
# 2           36/S  Not present  42/XL        42/XL
# 3           36/S         38/M  42/XL        42/XL
# 4           36/S         38/M  42/XL  Not present
# ..           ...          ...    ...          ...
# 283  Not present         38/M  42/XL        42/XL
# 284         36/S         38/M  42/XL        42/XL
# 285         36/S         38/M  42/XL  Not present
# 286         36/S         38/M  42/XL        42/XL
# 287  Not present         38/M  42/XL        42/XL
#
# [288 rows x 4 columns]

# %%
Montesize_final.to_csv('monte1_final_copy.csv')

# %%
style_code=[]
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5)          #taking each url one by one as an input
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/p')
        style_code.append(description.text)
    except NoSuchElementException :
        style_code.append('Not present')

# %%
len(style_code)
# Out:
# 288

# %%
style_code
# Out:
# ['',
#  'Not present',
#  '',
#  '',
#  '',
#  'Not present',
#  '',
#  'Not present',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Not present',
#  '',
#  '',
#  '',
#  'Not present',
#  'Not present',
#  '',
#  '',
#  'Not present',
#  'Not present',
#  '',
#  'Not present',
#  '',
#  '',
#  'Not present',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Not present',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Not present',
#  '',
#  '',
#  '',
#  '',
#  'Not present',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Not present',
#  '',
#  '',
#  'Not present',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Not present',
#  'Not present',
#  '',
#  '',
#  'Not present',
#  'Not present',
#  'Not present',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Not present',
#  '',
#  '',
#  '',
#  'Not present',
#  '',
#  '',
#  '',
#  '',
#  'Not present',
#  '',
#  'Not present',
# ...

# %%
#fetching url to open each product
productnew_url = []
start=0
end=1
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        productnew_url.append(i.get_attribute('href'))

# %%
style_codenew=[]
for i in productnew_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/p')
        style_codenew.append(description.text)
    except NoSuchElementException :
        style_codenew.append('Not present')

# %%
style_codenew
# Out:
# ['2230101396-3',
#  'Not present',
#  '2230101301-5',
#  '222057176-1',
#  'Not present',
#  '223060750-2',
#  'Not present',
#  '223060128-1',
#  '223060544-1',
#  '223060418-1',
#  '223060556-2',
#  '223060589-1',
#  '223060589-2',
#  '223060621-1',
#  '223060621-2',
#  '223060653-1',
#  '223060030TS-2',
#  '223060032TS-1',
#  'Not present',
#  '223060486-2']

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-current slick-active"]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=6
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[8]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')

# %%
len(product_url)
# Out:
# 288

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-navy-blue-printed-round-neck-half-sleeve-t-shirt-223062231-1',
#  'https://www.montecarlo.in/products/monte-carlo-men-white-printed-t-shirt-38647',
#  'https://www.montecarlo.in/products/monte-carlo-men-rust-orange-printed-t-shirt-38645',
#  'https://www.montecarlo.in/products/monte-carlo-men-yellow-printed-t-shirt-38644',
#  'https://www.montecarlo.in/products/monte-carlo-men-red-printed-t-shirt-38639',
#  'https://www.montecarlo.in/products/monte-carlo-men-navy-blue-printed-t-shirt-38638',
#  'https://www.montecarlo.in/products/monte-carlo-men-white-printed-t-shirt-38637',
#  'https://www.montecarlo.in/products/monte-carlo-men-olive-printed-t-shirt-38625',
#  'https://www.montecarlo.in/products/monte-carlo-men-navy-blue-printed-t-shirt-38624',
#  'https://www.montecarlo.in/products/monte-carlo-men-grey-printed-t-shirt-38623',
#  'https://www.montecarlo.in/products/monte-carlo-men-blue-printed-t-shirt-38615',
# ...

# %%
style=[]
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/p')
        style.append(description.text)
    except NoSuchElementException :
        style.append('Not present')

# %%
len(style)
# Out:
# 288

# %%
style
# Out:
# ['223062231-1',
#  '223060605-2',
#  '223060599-2',
#  '223060599-1',
#  '223060536-1',
#  '223060531-2',
#  '223060531-1',
#  '223060491-2',
#  '223060491-1',
#  '223060465-2',
#  '223060436-1',
#  '223060247-2',
#  '223060226-1',
#  '223060034TS-4',
#  '223060034TS-1',
#  '223060022TS-2',
#  '223060575-2',
#  '223060750-2',
#  '223060750-1',
#  '223060648-2',
#  '223060648-1',
#  '223060642-2',
#  '223060560-1',
#  '223060545-3',
#  '223060541-2',
#  '223060541-1',
#  '223060535-1',
#  '223060499-2',
#  '223060486-2',
#  '223060032TS-2',
#  '223060032TS-1',
#  '223060030TS-2',
#  '223060653-1',
#  '223060621-2',
#  '223060621-1',
#  '223060589-2',
#  '223060589-1',
#  '223060556-2',
#  '223060556-1',
#  '223060553-2',
#  '22303401-25',
#  '22303650-7',
#  '222057179-1',
#  '222057174-1',
#  '222057150-1',
#  '222055445-1',
#  '222055418-2',
#  '222055418-1',
#  '223062231-1',
#  '223060605-2',
#  '223060599-2',
#  '223060599-1',
#  '223060536-1',
#  '223060531-2',
# ...

# %%
# Creating Dataframe-
import pandas as pd
Style_final=pd.DataFrame({'Sno':style, 'Productcode':style})
Style_final
# Out:
#              Sno  Productcode
# 0    223062231-1  223062231-1
# 1    223060605-2  223060605-2
# 2    223060599-2  223060599-2
# 3    223060599-1  223060599-1
# 4    223060536-1  223060536-1
# ..           ...          ...
# 283  222057174-1  222057174-1
# 284  222057150-1  222057150-1
# 285  222055445-1  222055445-1
# 286  222055418-2  222055418-2
# 287  222055418-1  222055418-1
#
# [288 rows x 2 columns]

# %%
Style_final.to_csv('style_final_copy.csv')

# %%
color=[]
brand=[]
occassion=[]
commodity=[]
mrp=[]
material=[]
origin=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[2]/p')
        color.append(description.text)
    except NoSuchElementException :
        color.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[3]/p')
        brand.append(description.text)
    except NoSuchElementException :
        brand.append('Not present')

# %%
len(color)
# Out:
# 288

# %%
color
# Out:
# ['Navy Blue',
#  'White',
#  'Orange',
#  'Yellow',
#  'Not present',
#  'Navy Blue',
#  'White',
#  'Olive',
#  'Navy Blue',
#  'Grey',
#  'Not present',
#  'Blue',
#  'Blue',
#  'Blue',
#  'Beige',
#  'Brown',
#  'Blue',
#  'Blue',
#  'Not present',
#  'Blue',
#  'Not present',
#  'Black',
#  'Not present',
#  'Olive',
#  'Blue',
#  'Not present',
#  'Blue',
#  'Pink',
#  'Navy Blue',
#  'Green',
#  'Yellow',
#  'Yellow',
#  'Navy Blue',
#  'Navy Blue',
#  'Red',
#  'Not present',
#  'Green',
#  'Not present',
#  'White',
#  'Not present',
#  'Cream',
#  'Blue',
#  'Not present',
#  'Blue',
#  'Not present',
#  'Yellow',
#  'Not present',
#  'White',
#  'Not present',
#  'White',
#  'Orange',
#  'Yellow',
#  'Not present',
#  'Navy Blue',
#  'White',
#  'Olive',
#  'Navy Blue',
#  'Grey',
#  'Not present',
#  'Blue',
#  'Blue',
#  'Blue',
#  'Beige',
#  'Brown',
#  'Blue',
#  'Blue',
#  'Green',
#  'Blue',
#  'White',
#  'Black',
#  'Not present',
#  'Olive',
#  'Blue',
# ...

# %%
len(brand)
# Out:
# 288

# %%
brand
# Out:
# ['Monte Carlo',
#  'Not present',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Not present',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Not present',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Not present',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Not present',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Not present',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Not present',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Not present',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Not present',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Monte Carlo',
#  'Not present',
#  'Monte Carlo',
# ...

# %%
# Creating Dataframe-
import pandas as pd
color_brand=pd.DataFrame({'color':color, 'brand':brand})
color_brand
# Out:
#            color        brand
# 0      Navy Blue  Monte Carlo
# 1          White  Not present
# 2         Orange  Monte Carlo
# 3         Yellow  Monte Carlo
# 4    Not present  Monte Carlo
# ..           ...          ...
# 283         Blue  Not present
# 284          Red  Monte Carlo
# 285       Yellow  Not present
# 286        Black  Monte Carlo
# 287        White  Monte Carlo
#
# [288 rows x 2 columns]

# %%
color_brand.to_csv('color_brand_copy.csv')

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-current slick-active"]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=6
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[8]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')

# %%
len(product_url)
# Out:
# 288

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-navy-blue-printed-round-neck-half-sleeve-t-shirt-223062231-1',
#  'https://www.montecarlo.in/products/monte-carlo-men-white-printed-t-shirt-38647',
#  'https://www.montecarlo.in/products/monte-carlo-men-rust-orange-printed-t-shirt-38645',
#  'https://www.montecarlo.in/products/monte-carlo-men-yellow-printed-t-shirt-38644',
#  'https://www.montecarlo.in/products/monte-carlo-men-red-printed-t-shirt-38639',
#  'https://www.montecarlo.in/products/monte-carlo-men-navy-blue-printed-t-shirt-38638',
#  'https://www.montecarlo.in/products/monte-carlo-men-white-printed-t-shirt-38637',
#  'https://www.montecarlo.in/products/monte-carlo-men-olive-printed-t-shirt-38625',
#  'https://www.montecarlo.in/products/monte-carlo-men-navy-blue-printed-t-shirt-38624',
#  'https://www.montecarlo.in/products/monte-carlo-men-grey-printed-t-shirt-38623',
#  'https://www.montecarlo.in/products/monte-carlo-men-blue-printed-t-shirt-38615',
# ...

# %%
occassion=[]
commodity=[]
mrp=[]
material=[]
origin=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[7]/p')
        occassion.append(description.text)
    except NoSuchElementException :
        occassion.append('Not present')
        
   
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[12]/p')
        mrp.append(description.text)
    except NoSuchElementException :
        mrp.append('Not present')

# %%
len(occassion)
# Out:
# 288

# %%
occassion
# Out:
# ['',
#  'Casual',
#  '',
#  '',
#  '',
#  'Casual',
#  'Casual',
#  'Casual',
#  'Casual',
#  'Casual',
#  'Not present',
#  'Not present',
#  'Casual',
#  'Not present',
#  'Casual',
#  'Casual',
#  'Not present',
#  'Casual',
#  'Not present',
#  'Casual',
#  'Not present',
#  'Casual',
#  'Casual',
#  'Casual',
#  'Casual',
#  'Casual',
#  'Casual',
#  '',
#  'Not present',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Casual',
#  'Casual',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Not present',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
len(mrp)
# Out:
# 288

# %%
mrp
# Out:
# ['Rs. 1,390.00',
#  'Rs. 1,345.00',
#  'Rs. 1,345.00',
#  'Rs. 1,345.00',
#  'Rs. 1,490.00',
#  'Not present',
#  'Rs. 1,440.00',
#  'Rs. 1,700.00',
#  'Not present',
#  'Rs. 1,545.00',
#  'Rs. 1,645.00',
#  'Rs. 1,740.00',
#  'Rs. 1,645.00',
#  'Not present',
#  'Rs. 1,945.00',
#  'Rs. 1,895.00',
#  'Not present',
#  'Rs. 1,440.00',
#  'Rs. 1,440.00',
#  'Rs. 1,895.00',
#  'Rs. 1,895.00',
#  'Rs. 1,700.00',
#  'Rs. 990.00',
#  'Rs. 945.00',
#  'Rs. 1,440.00',
#  'Rs. 1,440.00',
#  'Not present',
#  'Cotton Blend',
#  'Not present',
#  'Rs. 1,695.00',
#  'Rs. 1,695.00',
#  'Not present',
#  'Rs. 1,895.00',
#  'Rs. 1,245.00',
#  'Rs. 1,245.00',
#  'Rs. 1,295.00',
#  'Rs. 1,295.00',
#  'Rs. 1,345.00',
#  'Rs. 1,345.00',
#  'Rs. 990.00',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Not present',
#  'Rs. 1,175.00',
#  'Cotton Blend',
#  'Rs. 1,145.00',
#  'Rs. 1,345.00',
#  'Rs. 1,345.00',
#  'Rs. 1,390.00',
#  'Rs. 1,345.00',
#  'Not present',
#  'Rs. 1,345.00',
#  'Rs. 1,490.00',
# ...

# %%
# Creating Dataframe-
import pandas as pd
occassion_mrp=pd.DataFrame({'occassion':occassion, 'mrp':mrp})
occassion_mrp
# Out:
#     occassion           mrp
# 0              Rs. 1,390.00
# 1      Casual  Rs. 1,345.00
# 2              Rs. 1,345.00
# 3              Rs. 1,345.00
# 4              Rs. 1,490.00
# ..        ...           ...
# 283             Not present
# 284    Casual  Cotton Blend
# 285    Casual   Not present
# 286    Casual  Rs. 1,345.00
# 287    Casual  Rs. 1,345.00
#
# [288 rows x 2 columns]

# %%
occassion_mrp.to_csv('occassion_mrp_copy.csv')

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-current slick-active"]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=6
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[8]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')

# %%
len(product_url)
# Out:
# 288

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-navy-blue-printed-round-neck-half-sleeve-t-shirt-223062231-1',
#  'https://www.montecarlo.in/products/monte-carlo-men-white-printed-t-shirt-38647',
#  'https://www.montecarlo.in/products/monte-carlo-men-rust-orange-printed-t-shirt-38645',
#  'https://www.montecarlo.in/products/monte-carlo-men-yellow-printed-t-shirt-38644',
#  'https://www.montecarlo.in/products/monte-carlo-men-red-printed-t-shirt-38639',
#  'https://www.montecarlo.in/products/monte-carlo-men-navy-blue-printed-t-shirt-38638',
#  'https://www.montecarlo.in/products/monte-carlo-men-white-printed-t-shirt-38637',
#  'https://www.montecarlo.in/products/monte-carlo-men-olive-printed-t-shirt-38625',
#  'https://www.montecarlo.in/products/monte-carlo-men-navy-blue-printed-t-shirt-38624',
#  'https://www.montecarlo.in/products/monte-carlo-men-grey-printed-t-shirt-38623',
#  'https://www.montecarlo.in/products/monte-carlo-men-blue-printed-t-shirt-38615',
# ...

# %%
material=[]
origin=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[13]/p')
        material.append(description.text)
    except NoSuchElementException :
        material.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[15]/p')
        origin.append(description.text)
    except NoSuchElementException :
        origin.append('Not present')

# %%
len(material)
# Out:
# 288

# %%
material
# Out:
# ['Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Linen',
#  'Linen',
#  'Linen',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Not present',
#  'Cotton Blend',
#  'Not present',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Not present',
#  'Machine Wash',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Machine Wash',
#  'Machine Wash',
#  'Cotton Blend',
#  'Not present',
#  'Machine Wash',
#  'Not present',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Not present',
#  'Not present',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
# ...

# %%
len(origin)
# Out:
# 288

# %%
origin
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'India',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'Not present',
#  'India',
#  'Not present',
#  'India',
#  'Not present',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'Not present',
#  'India',
#  'Not present',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'Monte Carlo Fashions Limited Unit-2, 231, Industrial Area - A, Ludhiana-141003, Punjab, India',
#  'India',
#  'India',
#  'Not present',
#  'India',
#  'India',
#  'India',
#  'Not present',
#  'India',
#  'India',
#  'Not present',
#  'India',
#  'India',
# ...

# %%
return_policy=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/div[3]/button[2]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/div[3]/div[2]/p')
        return_policy.append(description.text)
    except NoSuchElementException :
        return_policy.append('Not present')

# %%
len(return_policy)
# Out:
# 288

# %%
return_policy
# Out:
# ['Not present',
#  'This item is eligible for return within 7 days of delivery.',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'This item is eligible for return within 7 days of delivery.',
#  'Not present',
#  'Not present',
#  'This item is eligible for return within 7 days of delivery.',
#  'This item is eligible for return within 7 days of delivery.',
#  'This item is eligible for return within 7 days of delivery.',
#  'This item is eligible for return within 7 days of delivery.',
#  'Not present',
#  'Not present',
#  'Not present',
#  'This item is eligible for return within 7 days of delivery.',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'This item is eligible for return within 7 days of delivery.',
#  'Not present',
#  'Not present',
#  'Not present',
#  'This item is eligible for return within 7 days of delivery.',
#  'This item is eligible for return within 7 days of delivery.',
# ...

# %%
# Creating Dataframe-
import pandas as pd
return_policy=pd.DataFrame({'return':return_policy})
return_policy
# Out:
#                                                 return
# 0                                          Not present
# 1    This item is eligible for return within 7 days...
# 2                                          Not present
# 3                                          Not present
# 4                                          Not present
# ..                                                 ...
# 283                                        Not present
# 284                                        Not present
# 285                                        Not present
# 286                                        Not present
# 287                                        Not present
#
# [288 rows x 1 columns]

# %%
return_policy.to_csv('return_policy_copy.csv')

# %%
# Creating Dataframe-
import pandas as pd
material=pd.DataFrame({'material':material})
material
# Out:
#          material
# 0    Cotton Blend
# 1    Cotton Blend
# 2    Cotton Blend
# 3    Cotton Blend
# 4    Cotton Blend
# ..            ...
# 283
# 284
# 285
# 286
# 287
#
# [288 rows x 1 columns]

# %%
material.to_csv('material_copy.csv')

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-current slick-active"]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=6
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH, '/html/body/div[8]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')

# %%
len(product_url)
# Out:
# 288

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-navy-blue-printed-round-neck-half-sleeve-t-shirt-223062231-1',
#  'https://www.montecarlo.in/products/monte-carlo-men-white-printed-t-shirt-38647',
#  'https://www.montecarlo.in/products/monte-carlo-men-rust-orange-printed-t-shirt-38645',
#  'https://www.montecarlo.in/products/monte-carlo-men-yellow-printed-t-shirt-38644',
#  'https://www.montecarlo.in/products/monte-carlo-men-red-printed-t-shirt-38639',
#  'https://www.montecarlo.in/products/monte-carlo-men-navy-blue-printed-t-shirt-38638',
#  'https://www.montecarlo.in/products/monte-carlo-men-white-printed-t-shirt-38637',
#  'https://www.montecarlo.in/products/monte-carlo-men-olive-printed-t-shirt-38625',
#  'https://www.montecarlo.in/products/monte-carlo-men-navy-blue-printed-t-shirt-38624',
#  'https://www.montecarlo.in/products/monte-carlo-men-grey-printed-t-shirt-38623',
#  'https://www.montecarlo.in/products/monte-carlo-men-blue-printed-t-shirt-38615',
# ...

# %%
origin_new=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[15]/p')
        origin_new.append(description.text)
    except NoSuchElementException :
        origin_new.append('Not present')

# %%
len(origin_new)
# Out:
# 288

# %%
origin_new
# Out:
# ['India',
#  'India',
#  'India',
#  'India',
#  'Not present',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'Monte Carlo Fashions Limited Unit-2, 231, Industrial Area - A, Ludhiana-141003, Punjab, India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'Monte Carlo Fashions Limited Unit-2, 231, Industrial Area - A, Ludhiana-141003, Punjab, India',
#  'Not present',
#  'India',
#  'India',
#  'Monte Carlo Fashions Limited Unit-2, 231, Industrial Area - A, Ludhiana-141003, Punjab, India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
# ...

# %%
# Creating Dataframe-
import pandas as pd
origin=pd.DataFrame({'origin':origin_new})
origin
# Out:
#                                                 origin
# 0                                                India
# 1                                                India
# 2                                                India
# 3                                                India
# 4                                          Not present
# ..                                                 ...
# 283                                              India
# 284  Monte Carlo Fashions Limited Unit-2, 231, Indu...
# 285                                              India
# 286                                              India
# 287                                              India
#
# [288 rows x 1 columns]

# %%
origin.to_csv('origin_copy.csv')

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-active"][1]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=1
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "][1]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 44

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/monte-carlo-men-blue-printed-short-33125',
#  'https://www.montecarlo.in/products/rock-it-men-grey-solid-short-38380',
#  'https://www.montecarlo.in/products/rock-it-men-grey-solid-short-set-38284',
#  'https://www.montecarlo.in/products/rock-it-men-blue-solid-short-set-38283',
#  'https://www.montecarlo.in/products/men-green-printed-short-2230101274-1',
#  'https://www.montecarlo.in/products/men-blue-printed-short-2230101274-2',
#  'https://www.montecarlo.in/products/men-navy-blue-solid-regular-fit-short-2240101973-2',
#  'https://www.montecarlo.in/products/rock-it-mens-grey-self-design-short-24908',
#  'https://www.montecarlo.in/products/rock-it-men-black-self-design-shorts-31262',
#  'https://www.montecarlo.in/products/rock-it-men-black-solid-short-38385',
#  'https://www.montecarlo.in/products/rock-it-mens-black-plain-short-24904',
#  'https://www.montecarlo.in/products/rock-it-mens-black-self-design-short-24902',
# ...

# %%
##Creating Empty List for different attributes-
title_new = []
title_tags = driver.find_elements(By.XPATH, '//div[@class="title-wish"]/a')
for i in title_tags:
    title=i.text
    title_new.append(title)

# %%
len(title_new)
# Out:
# 44

# %%
title_new
# Out:
# ['Men Blue Printed Short',
#  'Men Grey Solid Short',
#  'Men Grey Solid Short Set',
#  'Men Blue Solid Short Set',
#  'Men Green Printed Short',
#  'Men Blue Printed Short',
#  'Men Navy Blue Solid Regular Fit Short',
#  'Mens Grey Self Design Short',
#  'Men Black Self Design Shorts',
#  'Men Black Solid Short',
#  'Mens Black Plain Short',
#  'Mens Black Self Design Short',
#  'Mens Olive Self Design Short',
#  'Mens NAvy Blue Self Design Short',
#  'Mens Grey Self Design Short',
#  'Mens Grey Printed Short',
#  'Mens Navy Blue Plain Short',
#  'Mens Navy Blue Self Design Short',
#  'Mens Maroon Self Design Short',
#  'Mens Olive Printed Short',
#  'Men Grey Self Design Shorts',
#  'Men Navy Blue Self Design Shorts',
#  'Men Black Self Design Short',
#  'Men NAvy Blue Solid Short',
#  'Men Grey Self Design Shorts',
#  'Men Royal Blue Self Design Shorts',
#  'Men Blue Solid Short',
#  'Men Blue Solid Short',
#  'Men Blue Self Design Short',
#  'Men Grey Self Design Short',
# ...

# %%
size_1=[]
size_2=[]
size_3=[]
size_4=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[1]/label')
        size_1.append(description.text)
    except NoSuchElementException :
        size_1.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[2]/label')
        size_2.append(description.text)
    except NoSuchElementException :
        size_2.append('Not present')
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[3]/label')
        size_3.append(description.text)
    except NoSuchElementException :
        size_3.append('Not present')
        
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[4]/label')
        size_4.append(description.text)
    except NoSuchElementException :
        size_4.append('Not present')

# %%
size_1
# Out:
# ['28',
#  '36/S',
#  '36/S',
#  'Not present',
#  'Not present',
#  '36/S',
#  'Not present',
#  '32/M',
#  '30/S',
#  '36/S',
#  '32/M',
#  '32/M',
#  'Not present',
#  'Not present',
#  '32/M',
#  '32/M',
#  '32/M',
#  'Not present',
#  '32/M',
#  '32/M',
#  'Not present',
#  '30/S',
#  '30/S',
#  '36/S',
#  '30/S',
#  '30/S',
#  '28',
#  '28',
#  '36/S',
#  'Not present',
#  '36/S',
#  '36/S',
#  '36/S',
#  'Not present',
#  '36/S',
#  'Not present',
#  '36/S',
#  '36/S',
#  '36/S',
#  'Not present',
#  '36/S',
#  '36/S',
#  'Not present',
#  '32/M']

# %%
len(size_1)
# Out:
# 44

# %%
# Creating Dataframe-
import pandas as pd
monte2_titlesize=pd.DataFrame({'title':title_new, 'Size1':size_1, 'Size2':size_2, 'Size3':size_3, 'Size4':size_4})
monte2_titlesize
# Out:
#                                     title        Size1        Size2  \
# 0                  Men Blue Printed Short           28           30
# 1                    Men Grey Solid Short         36/S         38/M
# 2                Men Grey Solid Short Set         36/S         38/M
# 3                Men Blue Solid Short Set  Not present  Not present
# 4                 Men Green Printed Short  Not present  Not present
# 5                  Men Blue Printed Short         36/S         38/M
# 6   Men Navy Blue Solid Regular Fit Short  Not present  Not present
# 7             Mens Grey Self Design Short         32/M         34/L
# 8            Men Black Self Design Shorts         30/S         32/M
# 9                   Men Black Solid Short         36/S         38/M
# 10                 Mens Black Plain Short         32/M         34/L
# 11           Mens Black Self Design Short         32/M  Not present
# 12           Mens Olive Self Design Short  Not present         34/L
# ...

# %%
monte2_titlesize.to_csv('monte2_titlesize_copy.csv')

# %%
style_code=[]
color=[]
brand=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(3) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/p')
        style_code.append(description.text)
    except NoSuchElementException :
        style_code.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(3) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[2]/p')
        color.append(description.text)
    except NoSuchElementException :
        color.append('Not present')   
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(3) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[3]/p')
        brand.append(description.text)
    except NoSuchElementException :
        brand.append('Not present')

# %%
len(style_code)
# Out:
# 44

# %%
# Creating Dataframe-
import pandas as pd
monte2_stylebrandcolor=pd.DataFrame({'style':style_code, 'color':color, 'brand':brand})
monte2_stylebrandcolor
# Out:
#              style        color        brand
# 0   2220830259SH-1         Blue  Monte Carlo
# 1     2230101306-1         Grey  Not present
# 2      Not present         Grey      Rock.it
# 3      Not present  Not present  Not present
# 4     2230101274-1        Green      Rock.it
# 5      Not present         Blue      Rock.it
# 6     2240101973-2  Not present      Rock.it
# 7     2210100824-2         Grey  Not present
# 8      Not present        Black      Rock.it
# 9     2230101306-6        Black      Rock.it
# 10    2210100822-2        Black      Rock.it
# 11     Not present        Black  Not present
# 12    2210100823-2  Not present      Rock.it
# 13    2210100826-2    Navy Blue      Rock.it
# 14     Not present         Grey  Not present
# 15    2210100825-2  Not present      Rock.it
# 16    2210100822-1    Navy Blue  Not present
# 17    2210100824-1    Navy Blue      Rock.it
# 18    2210100821-1       Maroon  Not present
# 19     Not present        Olive      Rock.it
# ...

# %%
monte2_stylebrandcolor.to_csv('monte2_stylebrandcolor_copy.csv')

# %%
occassion=[]
commodity=[]
mrp=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(3) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[7]/p')
        occassion.append(description.text)
    except NoSuchElementException :
        occassion.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(3) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[8]/p')
        commodity.append(description.text)
    except NoSuchElementException :
        commodity.append('Not present')   
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(3) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[10]/p')
        mrp.append(description.text)
    except NoSuchElementException :
        mrp.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte2_osc_commoditymrp=pd.DataFrame({'occassion':occassion, 'commodity':commodity, 'mrp':mrp})
monte2_osc_commoditymrp
# Out:
#       occassion    commodity              mrp
# 0   Not present        Short     Rs. 1,699.00
# 1        Casual        Short     Cotton Blend
# 2   Not present  Not present      Not present
# 3   Not present  Not present      Half Sleeve
# 4   Not present      Printed      Not present
# 5   Not present      Printed     Rs. 1,699.00
# 6        Casual  Not present     Rs. 1,199.00
# 7        Casual        Short      Not present
# 8        Casual  Not present     Rs. 1,445.00
# 9   Not present        Short      Not present
# 10       Casual  Not present     Rs. 1,199.00
# 11  Not present        Short     Rs. 1,199.00
# 12       Casual        Short       Rs. 999.00
# 13       Casual  Not present      Not present
# 14       Casual        Short       Rs. 999.00
# 15       Casual        Short     Rs. 1,199.00
# 16       Casual        Short      Not present
# 17       Casual        Short     Rs. 1,199.00
# 18  Not present        Short      Not present
# ...

# %%
monte2_osc_commoditymrp.to_csv('monte2_osc_commoditymrp_copy.csv')

# %%
mrp_new=[]
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(3) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[10]/p')
        mrp_new.append(description.text)
    except NoSuchElementException :
        mrp_new.append('Not present')

# %%
mrp_new
# Out:
# ['Rs. 1,699.00',
#  'Cotton Blend',
#  'Not present',
#  'Half Sleeve',
#  'Not present',
#  'Rs. 1,699.00',
#  'Rs. 1,199.00',
#  'Rs. 1,199.00',
#  'Not present',
#  'Cotton Blend',
#  'Rs. 1,199.00',
#  'Rs. 1,199.00',
#  'Not present',
#  'Rs. 999.00',
#  'Not present',
#  'Rs. 1,199.00',
#  'Rs. 1,199.00',
#  'Rs. 1,199.00',
#  'Not present',
#  'Rs. 1,199.00',
#  'Rs. 1,695.00',
#  'Not present',
#  'Rs. 1,595.00',
#  'Not present',
#  'Rs. 1,595.00',
#  'Rs. 1,445.00',
#  'Cotton Blend',
#  'Not present',
#  'Rs. 1,599.00',
#  'Not present',
#  'Polyester Blend',
#  'Not present',
#  'Polyester Blend',
#  'Polyester Blend',
#  'Not present',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Not present',
#  'Cotton Blend',
#  'Cotton Blend',
#  'Not present',
#  'Rs. 1,199.00']

# %%
material=[]
origin=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(3) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[11]/p')
        material.append(description.text)
    except NoSuchElementException :
        material.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(3) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[13]/p')
        origin.append(description.text)
    except NoSuchElementException :
        origin.append('Not present')

# %%
material
# Out:
# ['Cotton Lycra',
#  'Machine Wash',
#  'Not present',
#  'Rs. 2,299.00',
#  'Polyester Blend',
#  'Not present',
#  'Cotton Blend',
#  'Polyester',
#  'Polyester',
#  'Machine Wash',
#  'Polyester',
#  'Not present',
#  'Polyester',
#  'Polyester',
#  'Polyester',
#  'Polyester',
#  'Polyester',
#  'Not present',
#  'Polyester',
#  'Polyester',
#  'Not present',
#  'Polyester',
#  'Not present',
#  'Machine Wash',
#  'Polyester',
#  'Not present',
#  'Machine Wash',
#  'Not present',
#  'Polyester Blend',
#  'Polyester Blend',
#  'Machine Wash',
#  'Machine Wash',
#  'Machine Wash',
#  'Not present',
#  'Machine Wash',
#  'Not present',
#  'Machine Wash',
#  'Not present',
#  'Machine Wash',
#  'Not present',
#  'Machine Wash',
#  'Machine Wash',
#  'Not present',
#  'Polyester']

# %%
origin
# Out:
# ['Not present',
#  'Monte Carlo Fashions Limited Unit-2, 231, Industrial Area - A, Ludhiana-141003, Punjab, India',
#  'Machine Wash',
#  'Machine Wash',
#  'Not present',
#  'India',
#  'India',
#  'Not present',
#  'India',
#  'Monte Carlo Fashions Limited Unit-2, 231, Industrial Area - A, Ludhiana-141003, Punjab, India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'Not present',
#  'India',
#  'Not present',
#  'India',
#  'India',
#  'Not present',
#  'India',
#  'India',
#  'Not present',
#  'Monte Carlo Fashions Limited Unit-2, 231, Industrial Area - A, Ludhiana-141003, Punjab, India',
#  'India',
#  'Not present',
#  'Monte Carlo Fashions Limited Unit-2, 231, Industrial Area - A, Ludhiana-141003, Punjab, India',
#  'Monte Carlo Fashions Limited Unit-2, 231, Industrial Area - A, Ludhiana-141003, Punjab, India',
#  'Not present',
#  'India',
#  'Monte Carlo Fashions Limited Unit-2, 231, Industrial Area - A, Ludhiana-141003, Punjab, India',
#  'Not present',
# ...

# %%
# Creating Dataframe-
import pandas as pd
monte2_materialorigin=pd.DataFrame({'material':material, 'origin':origin})
monte2_materialorigin
# Out:
#            material                                             origin
# 0      Cotton Lycra                                        Not present
# 1      Machine Wash  Monte Carlo Fashions Limited Unit-2, 231, Indu...
# 2       Not present                                       Machine Wash
# 3      Rs. 2,299.00                                       Machine Wash
# 4   Polyester Blend                                        Not present
# 5       Not present                                              India
# 6      Cotton Blend                                              India
# 7         Polyester                                        Not present
# 8         Polyester                                              India
# 9      Machine Wash  Monte Carlo Fashions Limited Unit-2, 231, Indu...
# 10        Polyester                                              India
# 11      Not present                                              India
# ...

# %%
monte2_materialorigin.to_csv('monte2_materialorigin_copy.csv')

# %%
return_policy=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(3) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/div[3]/button[2]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/div[3]/div[2]/p')
        return_policy.append(description.text)
    except NoSuchElementException :
        return_policy.append('Not present')

# %%
len(return_policy)
# Out:
# 44

# %%
return_policy
# Out:
# ['Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'This item is eligible for return within 7 days of delivery.',
#  'Not present',
#  'Not present',
#  'Not present',
#  'This item is eligible for return within 7 days of delivery.',
#  'Not present',
#  'Not present',
#  'This item is eligible for return within 7 days of delivery.',
#  'Not present',
#  'Not present',
#  'This item is eligible for return within 7 days of delivery.',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'This item is eligible for return within 7 days of delivery.',
#  'This item is eligible for return within 7 days of delivery.',
#  'Not present',
#  'Not present',
#  'Not present',
#  'Not present',
#  'This item is eligible for return within 7 days of delivery.',
#  'Not present',
#  'Not present',
#  'This item is eligible for return within 7 days of delivery.',
#  'Not present',
#  'Not present',
#  'Not present',
# ...

# %%
##Creating Empty List for different attributes-
mrp_latest = []
mrp_tags = driver.find_elements(By.XPATH, '//span[@class="price price--highlight"]')
for i in mrp_tags:
    mrp=i.text
    mrp_latest.append(mrp)

# %%
[mrp_latest]
# Out:
# [['Sale price\nRs. 1,019',
#   'Sale price\nRs. 599',
#   'Sale price\nRs. 1,150',
#   'Sale price\nRs. 1,150',
#   'Sale price\nRs. 850',
#   'Sale price\nRs. 850',
#   'Sale price\nRs. 1,199.00',
#   'Sale price\nRs. 600',
#   'Sale price\nRs. 723',
#   'Sale price\nRs. 599',
#   'Sale price\nRs. 600',
#   'Sale price\nRs. 600',
#   'Sale price\nRs. 599',
#   'Sale price\nRs. 599',
#   'Sale price\nRs. 599',
#   'Sale price\nRs. 600',
#   'Sale price\nRs. 600',
#   'Sale price\nRs. 600',
#   'Sale price\nRs. 600',
#   'Sale price\nRs. 600',
#   'Sale price\nRs. 848',
#   'Sale price\nRs. 798',
#   'Sale price\nRs. 798',
#   'Sale price\nRs. 599',
#   'Sale price\nRs. 798',
#   'Sale price\nRs. 723',
#   'Sale price\nRs. 1,049',
#   'Sale price\nRs. 1,049',
#   'Sale price\nRs. 800',
#   'Sale price\nRs. 800',
#   'Sale price\nRs. 750',
#   'Sale price\nRs. 750',
#   'Sale price\nRs. 750',
#   'Sale price\nRs. 750',
#   'Sale price\nRs. 1,000',
#   'Sale price\nRs. 600',
# ...

# %%
# Creating Dataframe-
import pandas as pd
monte2_mrplatestreturn=pd.DataFrame({'return':return_policy, 'mrp':mrp_latest})
monte2_mrplatestreturn
# Out:
#                                                return  \
# 0                                         Not present
# 1                                         Not present
# 2                                         Not present
# 3                                         Not present
# 4   This item is eligible for return within 7 days...
# 5                                         Not present
# 6                                         Not present
# 7                                         Not present
# 8   This item is eligible for return within 7 days...
# 9                                         Not present
# 10                                        Not present
# 11  This item is eligible for return within 7 days...
# 12                                        Not present
# 13                                        Not present
# 14  This item is eligible for return within 7 days...
# 15                                        Not present
# ...

# %%
monte2_mrplatestreturn.to_csv('monte2_mrplatestreturn_copy.csv')

# %%
mrp_1=[]

# %%
##Creating Empty List for different attributes-
mrp_1 = []
start=0
end=6
for page in range(start,end):
    mrp_tags = driver.find_elements(By.XPATH, '//span[@class="price price--highlight"]')
    for i in title_tags:
        mrp=i.text
        mrp_1.append(mrp)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[8]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[57], line 8
#       6 mrp_tags = driver.find_elements(By.XPATH, '//span[@class="price price--highlight"]')
#       7 for i in title_tags:
# ----> 8     mrp=i.text
#       9     mrp_1.append(mrp)
#      10 next_button=driver.find_elements(By.XPATH,'/html/body/div[8]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:89, in WebElement.text(self)
#      86 @property
#      87 def text(self) -> str:
#      88     """The text of the element."""
# ---> 89     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:394, in WebElement._execute(self, command, params)
#     392     params = {}
#     393 params["id"] = self._id
# ...

# %%
#Creating Empty List for different attributes-
product_name = []
start=0
end=6
for page in range(start,end):
    product_tags = driver.find_elements(By.XPATH, '//div[@class="title-wish"]/a')

# %%
##Creating Empty List for different attributes-
title_new = []
title_tags = driver.find_elements(By.XPATH, '//div[@class="title-wish"]/a')
for i in title_tags:
    title=i.text
    title_new.append(title)

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-current slick-active"]')
subcategory_analyst.click()

# %%
#Creating Empty List for different attributes-
cost = []
start=0
end=6
for page in range(start,end):
    cost_tags = driver.find_elements(By.XPATH, '//span[@class="price price--highlight"]')
    for i in cost_tags:
        price=i.text
        cost.append(price)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[7]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')

# %%
cost
# Out:
# ['Sale price\nRs. 834',
#  'Sale price\nRs. 807',
#  'Sale price\nRs. 807',
#  'Sale price\nRs. 807',
#  'Sale price\nRs. 894',
#  'Sale price\nRs. 864',
#  'Sale price\nRs. 864',
#  'Sale price\nRs. 1,020',
#  'Sale price\nRs. 1,020',
#  'Sale price\nRs. 927',
#  'Sale price\nRs. 987',
#  'Sale price\nRs. 1,044',
#  'Sale price\nRs. 987',
#  'Sale price\nRs. 1,070',
#  'Sale price\nRs. 1,070',
#  'Sale price\nRs. 1,042',
#  'Sale price\nRs. 774',
#  'Sale price\nRs. 864',
#  'Sale price\nRs. 864',
#  'Sale price\nRs. 1,042',
#  'Sale price\nRs. 1,042',
#  'Sale price\nRs. 1,020',
#  'Sale price\nRs. 644',
#  'Sale price\nRs. 662',
#  'Sale price\nRs. 864',
#  'Sale price\nRs. 864',
#  'Sale price\nRs. 864',
#  'Sale price\nRs. 837',
#  'Sale price\nRs. 1,059',
#  'Sale price\nRs. 1,017',
#  'Sale price\nRs. 1,017',
#  'Sale price\nRs. 1,017',
#  'Sale price\nRs. 1,042',
#  'Sale price\nRs. 809',
#  'Sale price\nRs. 809',
#  'Sale price\nRs. 777',
#  'Sale price\nRs. 777',
# ...

# %%
# Creating Dataframe-
import pandas as pd
monte1_cost=pd.DataFrame({'mrp1':cost})
monte1_cost
# Out:
#                     mrp1
# 0    Sale price\nRs. 834
# 1    Sale price\nRs. 807
# 2    Sale price\nRs. 807
# 3    Sale price\nRs. 807
# 4    Sale price\nRs. 894
# ..                   ...
# 283  Sale price\nRs. 764
# 284  Sale price\nRs. 987
# 285  Sale price\nRs. 744
# 286  Sale price\nRs. 807
# 287  Sale price\nRs. 807
#
# [288 rows x 1 columns]

# %%
monte1_cost.to_csv('monte1_cost_copy.csv')

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-active"][2]')
subcategory_analyst.click()

# %%
#Creating Empty List for different attributes-
title_3 = []
start=0
end=3
for page in range(start,end):
    title_tags = driver.find_elements(By.XPATH, '//a[@class="product-item-meta__title"]')
    for i in title_tags:
        title=i.text
        title_3.append(title)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[7]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[3]')

# %%
len(title_3)
# Out:
# 144

# %%
title_3
# Out:
# ['Men Black Printed Regular Fit Lower',
#  'Men Grey Solid Regular Fit Lowers',
#  'Men Olive Self Design Regular Fit Lower',
#  'Men Black Self Design Regular Fit Lower',
#  'Men Grey Solid Regular Fit Lowers',
#  'Men Olive Solid Regular Fit Lowers',
#  'Men Teal Blue Printed Regular Fit Lower',
#  'Men Olive Regular Fit Lower',
#  'Men Grey Printed Regular Fit Lowers',
#  'Men Teal Blue Solid Regular Fit Lower',
#  'Men Olive Solid Regular Fit Lower',
#  'Men Maroon Solid Regular Fit Lower',
#  'Men Black Solid Regular Fit Lower',
#  'Men Grey Melange Solid Regular Fit Lower',
#  'Men Navy Blue Solid Regular Fit Lower',
#  'Men Navy Blue Solid Regular Fit Lower',
#  'Men Grey Solid Regular Fit Lower',
#  'Men Olive Check Regular Fit Lower',
#  'Men Navy Blue Solid Regular Fit Lower',
#  'Men Navy Blue Solid Regular Fit Lower',
#  'Men Olive Solid Regular Fit Lower',
#  'Men Blue Check Regular Fit Lower',
#  'Men White Solid Regular Fit Lower',
# ...

# %%
#fetching url to open each product
product_url = []
start=0
end=3
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 144

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-black-printed-regular-fit-lower-223061522-1',
#  'https://www.montecarlo.in/products/men-grey-solid-regular-fit-lowers-2230880732lo-1',
#  'https://www.montecarlo.in/products/men-olive-self-design-regular-fit-lower-223061528-2',
#  'https://www.montecarlo.in/products/men-black-self-design-regular-fit-lower-223061528-1',
#  'https://www.montecarlo.in/products/men-grey-solid-regular-fit-lowers-2230101525-1',
#  'https://www.montecarlo.in/products/men-olive-solid-regular-fit-lowers-2230101525-2',
#  'https://www.montecarlo.in/products/men-teal-blue-printed-regular-fit-lower-223061522-2',
#  'https://www.montecarlo.in/products/monte-carlo-men-olive-regular-fit-lower-37991',
#  'https://www.montecarlo.in/products/men-grey-printed-regular-fit-lowers-223061521-2',
#  'https://www.montecarlo.in/products/men-teal-blue-solid-regular-fit-lower-223061525-1',
#  'https://www.montecarlo.in/products/men-olive-solid-regular-fit-lower-22403609-11',
# ...

# %%
#Creating Empty List for different attributes-
mrp_3 = []
start=0
end=3
for page in range(start,end):
    mrp_tags = driver.find_elements(By.XPATH, '//span[@class="price price--highlight"]')
    for i in mrp_tags:
        mrp=i.text
        mrp_3.append(mrp)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[7]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[3]')

# %%
len(mrp_3)
# Out:
# 144

# %%
mrp_3
# Out:
# ['Sale price\nRs. 1,232',
#  'Sale price\nRs. 1,499',
#  'Sale price\nRs. 1,254',
#  'Sale price\nRs. 1,254',
#  'Sale price\nRs. 898',
#  'Sale price\nRs. 898',
#  'Sale price\nRs. 1,232',
#  'Sale price\nRs. 1,104',
#  'Sale price\nRs. 1,199',
#  'Sale price\nRs. 1,199',
#  'Sale price\nRs. 1,190',
#  'Sale price\nRs. 1,499.00',
#  'Sale price\nRs. 1,499.00',
#  'Sale price\nRs. 1,190',
#  'Sale price\nRs. 1,190',
#  'Sale price\nRs. 1,280',
#  'Sale price\nRs. 1,190',
#  'Sale price\nRs. 1,895',
#  'Sale price\nRs. 1,699.00',
#  'Sale price\nRs. 1,749.00',
#  'Sale price\nRs. 1,280',
#  'Sale price\nRs. 1,895',
#  'Sale price\nRs. 1,749.00',
#  'Sale price\nRs. 1,699.00',
#  'Sale price\nRs. 1,699.00',
#  'Sale price\nRs. 1,699.00',
#  'Sale price\nRs. 1,190',
#  'Sale price\nRs. 1,190',
#  'Sale price\nRs. 1,280',
#  'Sale price\nRs. 1,280',
#  'Sale price\nRs. 1,899.00',
#  'Sale price\nRs. 832',
#  'Sale price\nRs. 1,254',
#  'Sale price\nRs. 644',
#  'Sale price\nRs. 957',
# ...

# %%
# Creating Dataframe-
import pandas as pd
monte3_titlemrp=pd.DataFrame({'title_3':title_3, 'mrp_3':mrp_3})
monte3_titlemrp
# Out:
#                                       title_3                  mrp_3
# 0         Men Black Printed Regular Fit Lower  Sale price\nRs. 1,232
# 1           Men Grey Solid Regular Fit Lowers  Sale price\nRs. 1,499
# 2     Men Olive Self Design Regular Fit Lower  Sale price\nRs. 1,254
# 3     Men Black Self Design Regular Fit Lower  Sale price\nRs. 1,254
# 4           Men Grey Solid Regular Fit Lowers    Sale price\nRs. 898
# ..                                        ...                    ...
# 139  Men Navy Blue Printed Regular Fit Lowers  Sale price\nRs. 1,199
# 140         Men Olive Solid Regular Fit Lower  Sale price\nRs. 1,484
# 141    Men Navy Blue Stripe Regular Fit Lower  Sale price\nRs. 1,199
# 142     Men Olive Solid Polyester Blend Lower  Sale price\nRs. 1,499
# 143                   Men Beige Printed Lower  Sale price\nRs. 1,199
#
# [144 rows x 2 columns]

# %%
monte3_titlemrp.to_csv('monte3_titlemrp_copy.csv')

# %%
size_1=[]
size_2=[]
size_3=[]
size_4=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[1]/label')
        size_1.append(description.text)
    except NoSuchElementException :
        size_1.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[2]/label')
        size_2.append(description.text)
    except NoSuchElementException :
        size_2.append('Not present')
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[3]/label')
        size_3.append(description.text)
    except NoSuchElementException :
        size_3.append('Not present')
        
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[4]/label')
        size_4.append(description.text)
    except NoSuchElementException :
        size_4.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte3_size=pd.DataFrame({'Size3_1':size_1, 'Size3_2':size_2, 'Size3_3':size_3, 'Size3_4':size_4})
monte3_size
# Out:
#          Size3_1      Size3_2      Size3_3      Size3_4
# 0    Not present  Not present  Not present  Not present
# 1    Not present         40/L  Not present  Not present
# 2    Not present  Not present  Not present        42/XL
# 3    Not present  Not present  Not present  Not present
# 4    Not present         38/M  Not present        42/XL
# ..           ...          ...          ...          ...
# 139  Not present  Not present  Not present  Not present
# 140  Not present  Not present  Not present  Not present
# 141         36/S  Not present  Not present  Not present
# 142  Not present  Not present  Not present  Not present
# 143         36/S  Not present         40/L  Not present
#
# [144 rows x 4 columns]

# %%
monte3_size.to_csv('monte3_size_copy.csv')

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-active"][2]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=3
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 144

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-black-printed-regular-fit-lower-223061522-1',
#  'https://www.montecarlo.in/products/men-grey-solid-regular-fit-lowers-2230880732lo-1',
#  'https://www.montecarlo.in/products/men-olive-self-design-regular-fit-lower-223061528-2',
#  'https://www.montecarlo.in/products/men-black-self-design-regular-fit-lower-223061528-1',
#  'https://www.montecarlo.in/products/men-grey-solid-regular-fit-lowers-2230101525-1',
#  'https://www.montecarlo.in/products/men-olive-solid-regular-fit-lowers-2230101525-2',
#  'https://www.montecarlo.in/products/men-teal-blue-printed-regular-fit-lower-223061522-2',
#  'https://www.montecarlo.in/products/monte-carlo-men-olive-regular-fit-lower-37991',
#  'https://www.montecarlo.in/products/men-grey-printed-regular-fit-lowers-223061521-2',
#  'https://www.montecarlo.in/products/men-teal-blue-solid-regular-fit-lower-223061525-1',
#  'https://www.montecarlo.in/products/men-olive-solid-regular-fit-lower-22403609-11',
# ...

# %%
style_3=[]
color_3=[]
brand_3=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/p')
        style_3.append(description.text)
    except NoSuchElementException :
        style_3.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[2]/p')
        color_3.append(description.text)
    except NoSuchElementException :
        color_3.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[3]/p')
        brand_3.append(description.text)
    except NoSuchElementException :
        brand_3.append('Not present')

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-active"][2]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=3
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 144

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-black-printed-regular-fit-lower-223061522-1',
#  'https://www.montecarlo.in/products/men-grey-solid-regular-fit-lowers-2230880732lo-1',
#  'https://www.montecarlo.in/products/men-olive-self-design-regular-fit-lower-223061528-2',
#  'https://www.montecarlo.in/products/men-black-self-design-regular-fit-lower-223061528-1',
#  'https://www.montecarlo.in/products/men-grey-solid-regular-fit-lowers-2230101525-1',
#  'https://www.montecarlo.in/products/men-olive-solid-regular-fit-lowers-2230101525-2',
#  'https://www.montecarlo.in/products/men-teal-blue-printed-regular-fit-lower-223061522-2',
#  'https://www.montecarlo.in/products/monte-carlo-men-olive-regular-fit-lower-37991',
#  'https://www.montecarlo.in/products/men-grey-printed-regular-fit-lowers-223061521-2',
#  'https://www.montecarlo.in/products/men-teal-blue-solid-regular-fit-lower-223061525-1',
#  'https://www.montecarlo.in/products/men-olive-solid-regular-fit-lower-22403609-11',
# ...

# %%
return_3=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[2]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[2]/p')
        return_3.append(description.text)
    except NoSuchElementException :
        return_3.append('Not present')

# %%
len(return_3)
# Out:
# 288

# %%
return_3
# Out:
# ['Delivery & Return',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Not present',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Not present',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Not present',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Not present',
#  'Delivery & Return',
#  'Not present',
#  'Delivery & Return',
#  'Not present',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Not present',
#  'Delivery & Return',
#  'Not present',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Not present',
#  'Delivery & Return',
#  'Not present',
#  'Delivery & Return',
#  'Delivery & Return',
#  'Not present',
#  'Delivery & Return',
#  'Delivery & Return',
# ...

# %%
# Creating Dataframe-
import pandas as pd
monte3_return=pd.DataFrame({'Return_3':return_3})
monte3_return
# Out:
#                                               Return_3
# 0                                    Delivery & Return
# 1                                    Delivery & Return
# 2                                    Delivery & Return
# 3                                          Not present
# 4                                    Delivery & Return
# ..                                                 ...
# 283  This item is eligible for return within 7 days...
# 284                                        Not present
# 285  This item is eligible for return within 7 days...
# 286  This item is eligible for return within 7 days...
# 287  This item is eligible for return within 7 days...
#
# [288 rows x 1 columns]

# %%
monte3_return.to_csv('monte3_return_copy.csv')

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-active"][3]')
subcategory_analyst.click()

# %%
#Creating Empty List for different attributes-
title_4 = []
start=0
end=3
for page in range(start,end):
    title_tags = driver.find_elements(By.XPATH, '//a[@class="product-item-meta__title"]')
    for i in title_tags:
        title=i.text
        title_4.append(title)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[7]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[3]')

# %%
len(title_4)
# Out:
# 144

# %%
title_4
# Out:
# ['Men Blue Printed Pure Cotton Shirt',
#  'Men Navy Blue Printed Shirt',
#  'Men Black Printed Pure Cotton Shirt',
#  'Men Green Printed Cotton Blend Shirt',
#  'Men Blue Printed Shirt',
#  'Men White Solid Collar Full Sleeve Shirt',
#  'Men Green Stripe Collar Full Sleeve S...',
#  'Men Off White Check Collar Full Sleev...',
#  'Men Red Check Collar Full Sleeve Shirt',
#  'Men Blue Check Collar Full Sleeve Shirt',
#  'Men Blue Check Collar Full Sleeve Shirt',
#  'Men Navy Blue Printed Shirt',
#  'Men Yellow Check Collar Full Sleeve S...',
#  'Men Orange Stripe Collar Half Sleeve ...',
#  'Men Green Printed Spread Collar Full ...',
#  'Men Peach Solid Collar Full Sleeve Shirt',
#  'Men Blue Stripe Collar Half Sleeve Shirt',
#  'Men Navy Blue Printed Spread Collar F...',
#  'Men Sea Green Printed Mandarin Collar...',
#  'Men White Check Collar Full Sleeve Shirt',
#  'Men White Stripe Collar Full Sleeve S...',
#  'Men White Stripe Collar Full Sleeve S...',
# ...

# %%
#Creating Empty List for different attributes-
mrp_4 = []
start=0
end=3
for page in range(start,end):
    mrp_tags = driver.find_elements(By.XPATH, '//span[@class="price price--highlight"]')
    for i in mrp_tags:
        mrp=i.text
        mrp_4.append(mrp)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[7]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[3]')

# %%
mrp_4
# Out:
# ['Sale price\nRs. 1,409',
#  'Sale price\nRs. 1,229',
#  'Sale price\nRs. 1,229',
#  'Sale price\nRs. 1,409',
#  'Sale price\nRs. 1,099',
#  'Sale price\nRs. 2,899.00',
#  'Sale price\nRs. 2,999.00',
#  'Sale price\nRs. 1,699.00',
#  'Sale price\nRs. 1,699.00',
#  'Sale price\nRs. 1,999.00',
#  'Sale price\nRs. 1,999.00',
#  'Sale price\nRs. 1,229',
#  'Sale price\nRs. 1,999.00',
#  'Sale price\nRs. 2,849.00',
#  'Sale price\nRs. 1,799.00',
#  'Sale price\nRs. 2,799.00',
#  'Sale price\nRs. 2,849.00',
#  'Sale price\nRs. 1,799.00',
#  'Sale price\nRs. 2,699.00',
#  'Sale price\nRs. 1,999.00',
#  'Sale price\nRs. 1,399.00',
#  'Sale price\nRs. 1,399.00',
#  'Sale price\nRs. 2,799.00',
#  'Sale price\nRs. 2,699.00',
#  'Sale price\nRs. 2,899.00',
#  'Sale price\nRs. 1,899.00',
#  'Sale price\nRs. 1,699.00',
#  'Sale price\nRs. 2,299.00',
#  'Sale price\nRs. 2,299.00',
#  'Sale price\nRs. 1,699.00',
#  'Sale price\nRs. 2,299.00',
#  'Sale price\nRs. 2,299.00',
# ...

# %%
# Creating Dataframe-
import pandas as pd
monte4_titleprice=pd.DataFrame({'Title_4':title_4, 'Price_4':mrp_4})
monte4_titleprice
# Out:
#                                       Title_4                   Price_4
# 0          Men Blue Printed Pure Cotton Shirt     Sale price\nRs. 1,409
# 1                 Men Navy Blue Printed Shirt     Sale price\nRs. 1,229
# 2         Men Black Printed Pure Cotton Shirt     Sale price\nRs. 1,229
# 3        Men Green Printed Cotton Blend Shirt     Sale price\nRs. 1,409
# 4                      Men Blue Printed Shirt     Sale price\nRs. 1,099
# ..                                        ...                       ...
# 139  Men Maroon Check Spread Collar Full S...  Sale price\nRs. 2,149.00
# 140  Men Navy Blue Check Spread Collar Ful...  Sale price\nRs. 2,149.00
# 141  Men Blue Stripe Collar Half Sleeve Shirt  Sale price\nRs. 2,849.00
# 142  Men Black Printed Spread Collar Full ...  Sale price\nRs. 2,399.00
# 143  Men Grey Printed Spread Collar Full S...  Sale price\nRs. 1,999.00
#
# [144 rows x 2 columns]

# %%
monte4_titleprice.to_csv('monte4_titleprice_copy.csv')

# %%
#fetching url to open each product
product_url = []
start=0
end=3
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 144

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-blue-printed-pure-cotton-shirt-2230603157fs-1',
#  'https://www.montecarlo.in/products/men-navy-blue-printed-shirt-2230603053fs-1',
#  'https://www.montecarlo.in/products/monte-carlo-men-black-printed-pure-cotton-shirt-39716',
#  'https://www.montecarlo.in/products/monte-carlo-men-green-printed-cotton-blend-shirt-39715',
#  'https://www.montecarlo.in/products/monte-carlo-men-blue-printed-shirt-38669',
#  'https://www.montecarlo.in/products/men-white-solid-collar-full-sleeve-shirt-2240401209fs-1',
#  'https://www.montecarlo.in/products/men-green-stripe-collar-full-sleeve-shirt-2240401149fs-2',
#  'https://www.montecarlo.in/products/men-off-white-check-collar-full-sleeve-shirt-2240401070fs-2',
#  'https://www.montecarlo.in/products/men-red-check-collar-full-sleeve-shirt-2240401070fs-1',
#  'https://www.montecarlo.in/products/men-blue-check-collar-full-sleeve-shirt-2240401052fs-1',
# ...

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-active"][3]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=3
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 144

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-blue-printed-pure-cotton-shirt-2230603157fs-1',
#  'https://www.montecarlo.in/products/men-navy-blue-printed-shirt-2230603053fs-1',
#  'https://www.montecarlo.in/products/monte-carlo-men-black-printed-pure-cotton-shirt-39716',
#  'https://www.montecarlo.in/products/monte-carlo-men-green-printed-cotton-blend-shirt-39715',
#  'https://www.montecarlo.in/products/monte-carlo-men-blue-printed-shirt-38669',
#  'https://www.montecarlo.in/products/men-white-solid-collar-full-sleeve-shirt-2240401209fs-1',
#  'https://www.montecarlo.in/products/men-green-stripe-collar-full-sleeve-shirt-2240401149fs-2',
#  'https://www.montecarlo.in/products/men-off-white-check-collar-full-sleeve-shirt-2240401070fs-2',
#  'https://www.montecarlo.in/products/men-red-check-collar-full-sleeve-shirt-2240401070fs-1',
#  'https://www.montecarlo.in/products/men-blue-check-collar-full-sleeve-shirt-2240401052fs-1',
# ...

# %%
size_1=[]
size_2=[]
size_3=[]
size_4=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[1]/label')
        size_1.append(description.text)
    except NoSuchElementException :
        size_1.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[2]/label')
        size_2.append(description.text)
    except NoSuchElementException :
        size_2.append('Not present')
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[3]/label')
        size_3.append(description.text)
    except NoSuchElementException :
        size_3.append('Not present')
        
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[4]/label')
        size_4.append(description.text)
    except NoSuchElementException :
        size_4.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte4_size=pd.DataFrame({'Size1':size_1, 'Size2':size_2, 'Size3':size_3, 'Size4': size_4})
monte4_size
# Out:
#            Size1        Size2        Size3        Size4
# 0           36/S         38/M         40/L  Not present
# 1    Not present         38/M  Not present        42/XL
# 2           36/S  Not present         40/L  Not present
# 3           36/S         38/M  Not present        42/XL
# 4           36/S         38/M         40/L        42/XL
# ..           ...          ...          ...          ...
# 139         36/S         38/M         40/L        42/XL
# 140         36/S  Not present         40/L        42/XL
# 141         36/S         38/M         40/L        42/XL
# 142         36/S  Not present         40/L        42/XL
# 143  Not present         38/M         40/L        42/XL
#
# [144 rows x 4 columns]

# %%
monte4_size.to_csv('monte4_size_copy.csv')

# %%
style=[]
color=[]
brand=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/p')
        style.append(description.text)
    except NoSuchElementException :
        style.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[2]/p')
        color.append(description.text)
    except NoSuchElementException :
        color.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[3]/p/font/font')
        brand.append(description.text)
    except NoSuchElementException :
        brand.append('Not present')
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[39], line 14
#      10         style.append('Not present')
#      13 for i in product_url:
# ---> 14     driver.get(i)          #iterating each and every url to fetch price details
#      15     time.sleep(5)
#      16     try:
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
# ...

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-active"][3]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=3
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 144

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-blue-printed-pure-cotton-shirt-2230603157fs-1',
#  'https://www.montecarlo.in/products/men-navy-blue-printed-shirt-2230603053fs-1',
#  'https://www.montecarlo.in/products/monte-carlo-men-black-printed-pure-cotton-shirt-39716',
#  'https://www.montecarlo.in/products/monte-carlo-men-green-printed-cotton-blend-shirt-39715',
#  'https://www.montecarlo.in/products/monte-carlo-men-blue-printed-shirt-38669',
#  'https://www.montecarlo.in/products/men-white-solid-collar-full-sleeve-shirt-2240401209fs-1',
#  'https://www.montecarlo.in/products/men-green-stripe-collar-full-sleeve-shirt-2240401149fs-2',
#  'https://www.montecarlo.in/products/men-off-white-check-collar-full-sleeve-shirt-2240401070fs-2',
#  'https://www.montecarlo.in/products/men-red-check-collar-full-sleeve-shirt-2240401070fs-1',
#  'https://www.montecarlo.in/products/men-blue-check-collar-full-sleeve-shirt-2240401052fs-1',
# ...

# %%
style=[]
brand=[]
color=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/p')
        style.append(description.text)
    except NoSuchElementException :
        style.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[2]/p')
        brand.append(description.text)
    except NoSuchElementException :
        brand.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[3]/p')
        color.append(description.text)
    except NoSuchElementException :
        color.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte4_stylebrandcolor=pd.DataFrame({'Style':style, 'Brand':brand, 'Color':color})
monte4_stylebrandcolor
# Out:
#               Style      Brand        Color
# 0    2230603157FS-1       Blue  Monte Carlo
# 1       Not present  Navy Blue  Monte Carlo
# 2    2230603192FS-1      Black  Monte Carlo
# 3    2230603158FS-1      Green  Monte Carlo
# 4       Not present       Blue  Monte Carlo
# ..              ...        ...          ...
# 139  2240401033FS-2     Maroon  Monte Carlo
# 140  2240401033FS-1  Navy Blue  Monte Carlo
# 141  2240767498HS-2       Blue  Monte Carlo
# 142  2240401182FS-1      Black  Monte Carlo
# 143  2240401108FS-2       Grey  Monte Carlo
#
# [144 rows x 3 columns]

# %%
monte4_stylebrandcolor.to_csv('monte4_stylebrandcolor_copy.csv')

# %%
return_4=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[2]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[2]/p')
        return_4.append(description.text)
    except NoSuchElementException :
        return_4.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte4_return=pd.DataFrame({'return':return_4})
monte4_return
# Out:
#                                                 return
# 0    This item is eligible for return within 7 days...
# 1    This item is eligible for return within 7 days...
# 2    This item is eligible for return within 7 days...
# 3    This item is eligible for return within 7 days...
# 4    This item is eligible for return within 7 days...
# ..                                                 ...
# 139  This item is eligible for return within 7 days...
# 140  This item is eligible for return within 7 days...
# 141  This item is eligible for return within 7 days...
# 142  This item is eligible for return within 7 days...
# 143  This item is eligible for return within 7 days...
#
# [144 rows x 1 columns]

# %%
monte4_return.to_csv('monte4_return_copy.csv')

# %%
occassion=[]
material=[]
origin=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[7]/p')
        occassion.append(description.text)
    except NoSuchElementException :
        occassion.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[13]/p')
        material.append(description.text)
    except NoSuchElementException :
        material.append('Not present')    
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[15]/p')
        origin.append(description.text)
    except NoSuchElementException :
        origin.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte4_oscmaterialorigin=pd.DataFrame({'occassion':occassion, 'material':material, 'origin':origin})
monte4_oscmaterialorigin
# Out:
#     occassion      material       origin
# 0      Casual   100% Cotton        India
# 1      Casual   100% Cotton        India
# 2      Casual   100% Cotton        India
# 3      Casual  Cotton Blend        India
# 4      Casual   100% Cotton        India
# ..        ...           ...          ...
# 139    Casual   100% Cotton        India
# 140    Casual   100% Cotton  Not present
# 141    Casual    100% Linen        India
# 142    Casual   100% Cotton        India
# 143    Casual   100% Cotton        India
#
# [144 rows x 3 columns]

# %%
monte4_oscmaterialorigin.to_csv('monte4_oscmaterialorigin_copy.csv')

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-active"][4]')
subcategory_analyst.click()

# %%
#Creating Empty List for different attributes-
title_4 = []
start=0
end=2
for page in range(start,end):
    title_tags = driver.find_elements(By.XPATH, '//a[@class="product-item-meta__title"]')
    for i in title_tags:
        title=i.text
        title_4.append(title)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[7]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[2]')

# %%
len(title_4)
# Out:
# 96

# %%
title_4
# Out:
# ['Men Black Normal Wash Straight Fit Denim',
#  'Men Blue Light Wash Narrow Fit Denim',
#  'Men Blue Light Wash Straight Fit Denim',
#  'Men Navy Blue Light Wash Narrow Fit D...',
#  'Men Blue Light Wash Slim Fit Denim',
#  'Men Blue Light Wash Straight Fit Denim',
#  'Men Grey Light Wash Narrow Fit Denim',
#  'Men Blue Light Wash Skinny Fit Denim',
#  'Men Black Light Wash Slim Fit Denim',
#  'Men Grey Light Wash Narrow Fit Denim',
#  'Men Blue Light Wash Narrow Fit Denim',
#  'Men Black Light Wash Skinny Fit Denim',
#  'Men Blue Light Wash Straight Fit Denim',
#  'Men Black Solid Narrow Fit Denim',
#  'Men Blue Light Wash Skinny Fit Denim',
#  'Men Blue Light Wash Narrow Fit Denim',
#  'Men Black Light Wash Straight Fit Denim',
#  'Men Blue Light Wash Narrow Fit Denim',
#  'Men White Light Wash Skinny Fit Denim',
#  'Men Blue Light Wash Skinny Fit Denim',
#  'Men Blue Light Wash Skinny Fit Denim',
#  'Men Blue Light Wash Narrow Fit Denim',
# ...

# %%
#Creating Empty List for different attributes-
mrp_4 = []
start=0
end=2
for page in range(start,end):
    mrp_tags = driver.find_elements(By.XPATH, '//span[@class="price price--highlight"]')
    for i in mrp_tags:
        mrp=i.text
        mrp_4.append(mrp)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[7]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[2]')

# %%
len(mrp_4)
# Out:
# 96

# %%
mrp_4
# Out:
# ['Sale price\nRs. 2,999.00',
#  'Sale price\nRs. 2,799.00',
#  'Sale price\nRs. 2,699.00',
#  'Sale price\nRs. 2,899.00',
#  'Sale price\nRs. 2,599.00',
#  'Sale price\nRs. 2,799.00',
#  'Sale price\nRs. 2,799.00',
#  'Sale price\nRs. 2,799.00',
#  'Sale price\nRs. 2,299.00',
#  'Sale price\nRs. 2,899.00',
#  'Sale price\nRs. 2,599.00',
#  'Sale price\nRs. 3,599.00',
#  'Sale price\nRs. 3,099.00',
#  'Sale price\nRs. 2,499.00',
#  'Sale price\nRs. 2,799.00',
#  'Sale price\nRs. 2,999.00',
#  'Sale price\nRs. 2,899.00',
#  'Sale price\nRs. 2,899.00',
#  'Sale price\nRs. 2,799.00',
#  'Sale price\nRs. 2,899.00',
#  'Sale price\nRs. 2,999.00',
#  'Sale price\nRs. 2,899.00',
#  'Sale price\nRs. 2,899.00',
#  'Sale price\nRs. 3,099.00',
#  'Sale price\nRs. 3,399.00',
#  'Sale price\nRs. 2,699.00',
#  'Sale price\nRs. 2,999.00',
#  'Sale price\nRs. 2,999.00',
#  'Sale price\nRs. 2,399.00',
#  'Sale price\nRs. 2,299.00',
#  'Sale price\nRs. 2,799.00',
#  'Sale price\nRs. 2,599.00',
# ...

# %%
# Creating Dataframe-
import pandas as pd
monte5_titleprice=pd.DataFrame({'title':title_4, 'price':mrp_4})
monte5_titleprice
# Out:
#                                        title                     price
# 0   Men Black Normal Wash Straight Fit Denim  Sale price\nRs. 2,999.00
# 1       Men Blue Light Wash Narrow Fit Denim  Sale price\nRs. 2,799.00
# 2     Men Blue Light Wash Straight Fit Denim  Sale price\nRs. 2,699.00
# 3   Men Navy Blue Light Wash Narrow Fit D...  Sale price\nRs. 2,899.00
# 4         Men Blue Light Wash Slim Fit Denim  Sale price\nRs. 2,599.00
# ..                                       ...                       ...
# 91                 Men Grey Skinny Fit Denim     Sale price\nRs. 1,539
# 92            Men Navy Blue Narrow Fit Denim     Sale price\nRs. 1,594
# 93                Men Black Narrow Fit Denim     Sale price\nRs. 1,975
# 94    Men Blue Light Wash Regular Fit Denims     Sale price\nRs. 1,924
# 95     Men Brown Light Wash Narrow Fit Denim  Sale price\nRs. 3,599.00
#
# [96 rows x 2 columns]

# %%
monte5_titleprice.to_csv('monte5_titleprice_copy.csv')

# %%
#fetching url to open each product
product_url = []
start=0
end=2
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 96

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-black-normal-wash-straight-fit-denim-2240873617dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-narrow-fit-denim-2240873606dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-straight-fit-denim-2240873662dn-1',
#  'https://www.montecarlo.in/products/men-navy-blue-light-wash-narrow-fit-denim-2240873648dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-slim-fit-denim-2240873743dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-straight-fit-denim-2240873673dn-1',
#  'https://www.montecarlo.in/products/men-grey-light-wash-narrow-fit-denim-2240873715dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-skinny-fit-denim-2240873641dn-1',
#  'https://www.montecarlo.in/products/men-black-light-wash-slim-fit-denim-2240873667dn-1',
#  'https://www.montecarlo.in/products/men-grey-light-wash-narrow-fit-denim-2240873618dn-1',
# ...

# %%
size_1=[]
size_2=[]
size_3=[]
size_4=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[1]/label')
        size_1.append(description.text)
    except NoSuchElementException :
        size_1.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[2]/label')
        size_2.append(description.text)
    except NoSuchElementException :
        size_2.append('Not present')
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[3]/label')
        size_3.append(description.text)
    except NoSuchElementException :
        size_3.append('Not present')
        
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[4]/label')
        size_4.append(description.text)
    except NoSuchElementException :
        size_4.append('Not present')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[42], line 36
#      34 time.sleep(5)
#      35 try:
# ---> 36     description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[4]/label')
#      37     size_4.append(description.text)
#      38 except NoSuchElementException :
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# ...

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-active"][4]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=2
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-black-normal-wash-straight-fit-denim-2240873617dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-narrow-fit-denim-2240873606dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-straight-fit-denim-2240873662dn-1',
#  'https://www.montecarlo.in/products/men-navy-blue-light-wash-narrow-fit-denim-2240873648dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-slim-fit-denim-2240873743dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-straight-fit-denim-2240873673dn-1',
#  'https://www.montecarlo.in/products/men-grey-light-wash-narrow-fit-denim-2240873715dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-skinny-fit-denim-2240873641dn-1',
#  'https://www.montecarlo.in/products/men-black-light-wash-slim-fit-denim-2240873667dn-1',
#  'https://www.montecarlo.in/products/men-grey-light-wash-narrow-fit-denim-2240873618dn-1',
# ...

# %%
size_1=[]
size_2=[]
size_3=[]
size_4=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[1]/label')
        size_1.append(description.text)
    except NoSuchElementException :
        size_1.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[2]/label')
        size_2.append(description.text)
    except NoSuchElementException :
        size_2.append('Not present')
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[3]/label')
        size_3.append(description.text)
    except NoSuchElementException :
        size_3.append('Not present')
        
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[4]/label')
        size_4.append(description.text)
    except NoSuchElementException :
        size_4.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte5_size=pd.DataFrame({'Size1':size_1, 'Size2':size_2, 'Size3': size_3, 'Size4':size_4})
monte5_size
# Out:
#           Size1        Size2        Size3        Size4
# 0   Not present  Not present           32           34
# 1   Not present  Not present  Not present           36
# 2            30           32           34  Not present
# 3            30  Not present           34           36
# 4            28  Not present           32           34
# ..          ...          ...          ...          ...
# 91           28           30  Not present  Not present
# 92  Not present  Not present           32  Not present
# 93  Not present           30           32  Not present
# 94           28           30           32  Not present
# 95  Not present           30           32  Not present
#
# [96 rows x 4 columns]

# %%
monte5_size.to_csv('monte5_size_copy.csv')

# %%
style=[]
brand=[]
color=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/p')
        style.append(description.text)
    except NoSuchElementException :
        style.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[2]/p')
        color.append(description.text)
    except NoSuchElementException :
        color.append('Not present')    
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[3]/p')
        brand.append(description.text)
    except NoSuchElementException :
        brand.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte5_stylebrandcolor=pd.DataFrame({'Style':style, 'Brand':brand, 'Color': color})
monte5_stylebrandcolor
# Out:
#              Style        Brand        Color
# 0   2240873617DN-1  Not present
# 1   2240873606DN-1  Monte Carlo
# 2   2240873662DN-1  Monte Carlo
# 3   2240873648DN-1  Not present
# 4   2240873743DN-1  Monte Carlo
# ..             ...          ...          ...
# 91                  Monte Carlo  Not present
# 92     Not present  Monte Carlo    Navy Blue
# 93                  Monte Carlo  Not present
# 94                  Monte Carlo         Blue
# 95                  Monte Carlo        Brown
#
# [96 rows x 3 columns]

# %%
monte5_stylebrandcolor.to_csv('monte5_stylebrandcolor_copy.csv')

# %%
# !pip install selenium

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-active"][4]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=2
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 96

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-black-normal-wash-straight-fit-denim-2240873617dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-narrow-fit-denim-2240873606dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-straight-fit-denim-2240873662dn-1',
#  'https://www.montecarlo.in/products/men-navy-blue-light-wash-narrow-fit-denim-2240873648dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-slim-fit-denim-2240873743dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-straight-fit-denim-2240873673dn-1',
#  'https://www.montecarlo.in/products/men-grey-light-wash-narrow-fit-denim-2240873715dn-1',
#  'https://www.montecarlo.in/products/men-blue-light-wash-skinny-fit-denim-2240873641dn-1',
#  'https://www.montecarlo.in/products/men-black-light-wash-slim-fit-denim-2240873667dn-1',
#  'https://www.montecarlo.in/products/men-grey-light-wash-narrow-fit-denim-2240873618dn-1',
# ...

# %%
occassion=[]
material=[]
origin=[]
return_5=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[7]/p')
        occassion.append(description.text)
    except NoSuchElementException :
        occassion.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[11]/p')
        material.append(description.text)
    except NoSuchElementException :
        material.append('Not present')    
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[13]/p')
        origin.append(description.text)
    except NoSuchElementException :
        origin.append('Not present') 
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[2]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[2]/p')
        return_5.append(description.text)
    except NoSuchElementException :
        return_5.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte5_ocsmaterialoriginreturn=pd.DataFrame({'Occassion':occassion, 'material':material, 'origin': origin, 'return':return_5})
monte5_ocsmaterialoriginreturn
# Out:
#       Occassion      material       origin  \
# 0        Casual  Cotton Blend  Not present
# 1        Casual  Cotton Blend        India
# 2        Casual  Cotton Blend        India
# 3        Casual  Cotton Blend        India
# 4        Casual  Cotton Blend        India
# ..          ...           ...          ...
# 91  Not present  Cotton Blend        India
# 92  Not present   Not present  Not present
# 93       Casual  Cotton Blend        India
# 94       Casual  Cotton Blend        India
# 95       Casual  Cotton Blend        India
#
#                                                return
# 0                                         Not present
# 1   This item is eligible for return within 7 days...
# 2                                         Not present
# 3   This item is eligible for return within 7 days...
# 4   This item is eligible for return within 7 days...
# ..                                                ...
# 91  This item is eligible for return within 7 days...
# ...

# %%
monte5_ocsmaterialoriginreturn.to_csv('monte5_ocsmaterialoriginreturn_copy.csv')

# %%
# !pip install selenium

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '/html/body/div[6]/div/div/button[2]')
subcategory_analyst.click()

# %%
# Entering Designation in search box-
categorynew_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-active"][4]')
categorynew_analyst.click()

# %%
#Creating Empty List for different attributes-
title_new=[]
start=0
end=6
for page in range(start,end):
    title_tags = driver.find_elements(By.XPATH, '//a[@class="product-item-meta__title"]')
    for i in title_tags:
        title=i.text
        title_new.append(title)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[7]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')

# %%
len(title_new)
# Out:
# 288

# %%
title_new
# Out:
# ['Men Cream Solid Hooded Full Sleeve Sw...',
#  'Men Brown Solid Hooded Full Sleeve Sw...',
#  'Men Navy Blue Solid Hooded Full Sleev...',
#  'Men Navy Blue Solid Hooded Full Sleev...',
#  'Men Grey Solid Hooded Full Sleeve Swe...',
#  'Men Grey Solid Hooded Full Sleeve Swe...',
#  'Men Grey Solid Hooded Full Sleeve Swe...',
#  'Men Grey Solid Hooded Full Sleeve Swe...',
#  'Men Blue Solid Round Neck Full Sleeve...',
#  'Men Black Solid Round Neck Full Sleev...',
#  'Men White Solid Round Neck Full Sleev...',
#  'Men Blue Solid Stand Collar Full Slee...',
#  'Men Grey Printed Mock Collar Full Sle...',
#  'Men Grey Printed Mock Collar Full Sle...',
#  'Men Beige Stripe Hooded Full Sleeve S...',
#  'Men Blue Printed Round Neck Full Slee...',
#  'Men Olive Printed Round Neck Full Sle...',
#  'Men Navy Blue Printed Round Neck Full...',
#  'Men Black Printed Round Neck Full Sle...',
#  'Men Black Solid Round Neck Full Sleev...',
#  'Men Brown Solid Round Neck Full Sleev...',
# ...

# %%
#Creating Empty List for different attributes-
mrp_4 = []
start=0
end=6
for page in range(start,end):
    mrp_tags = driver.find_elements(By.XPATH, '//span[@class="price price--highlight"]')
    for i in mrp_tags:
        mrp=i.text
        mrp_4.append(mrp)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[7]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')

# %%
mrp_4
# Out:
# ['Sale price\nRs. 1,298',
#  'Sale price\nRs. 1,298',
#  'Sale price\nRs. 1,750',
#  'Sale price\nRs. 1,702',
#  'Sale price\nRs. 1,702',
#  'Sale price\nRs. 1,636',
#  'Sale price\nRs. 1,448',
#  'Sale price\nRs. 1,248',
#  'Sale price\nRs. 998',
#  'Sale price\nRs. 998',
#  'Sale price\nRs. 998',
#  'Sale price\nRs. 848',
#  'Sale price\nRs. 1,397',
#  'Sale price\nRs. 1,345',
#  'Sale price\nRs. 1,647',
#  'Sale price\nRs. 1,315',
#  'Sale price\nRs. 1,315',
#  'Sale price\nRs. 1,317',
#  'Sale price\nRs. 969',
#  'Sale price\nRs. 998',
#  'Sale price\nRs. 998',
#  'Sale price\nRs. 1,623',
#  'Sale price\nRs. 1,623',
#  'Sale price\nRs. 2,198',
#  'Sale price\nRs. 1,498',
#  'Sale price\nRs. 1,498',
#  'Sale price\nRs. 1,198',
#  'Sale price\nRs. 998',
#  'Sale price\nRs. 1,048',
#  'Sale price\nRs. 987',
#  'Sale price\nRs. 973',
#  'Sale price\nRs. 905',
#  'Sale price\nRs. 1,005',
#  'Sale price\nRs. 960',
#  'Sale price\nRs. 960',
#  'Sale price\nRs. 898',
# ...

# %%
len(mrp_4)
# Out:
# 288

# %%
# Creating Dataframe-
import pandas as pd
monte6_titleprice=pd.DataFrame({'title':title_new, 'price':mrp_4})
monte6_titleprice
# Out:
#                                         title                  price
# 0    Men Cream Solid Hooded Full Sleeve Sw...  Sale price\nRs. 1,298
# 1    Men Brown Solid Hooded Full Sleeve Sw...  Sale price\nRs. 1,298
# 2    Men Navy Blue Solid Hooded Full Sleev...  Sale price\nRs. 1,750
# 3    Men Navy Blue Solid Hooded Full Sleev...  Sale price\nRs. 1,702
# 4    Men Grey Solid Hooded Full Sleeve Swe...  Sale price\nRs. 1,702
# ..                                        ...                    ...
# 283                Men Peach Solid Sweatshirt    Sale price\nRs. 905
# 284  Men Blue Printed Mock Collar Full Sle...  Sale price\nRs. 1,397
# 285               Men Orange Solid Sweatshirt    Sale price\nRs. 965
# 286                 Men Blue Solid Sweatshirt    Sale price\nRs. 877
# 287  Men Turquoise Blue Solid Hooded Full ...  Sale price\nRs. 1,448
#
# [288 rows x 2 columns]

# %%
monte6_titleprice.to_csv('monte6_titleprice_copy.csv')

# %%
#fetching url to open each product
product_url = []
start=0
end=6
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 288

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-cream-solid-hooded-full-sleeve-sweatshirt-2230101550-2',
#  'https://www.montecarlo.in/products/men-brown-solid-hooded-full-sleeve-sweatshirt-2230101550-1',
#  'https://www.montecarlo.in/products/men-navy-blue-solid-hooded-full-sleeve-sweatshirt-223061327-1',
#  'https://www.montecarlo.in/products/men-navy-blue-solid-hooded-full-sleeve-sweatshirt-223061322-2',
#  'https://www.montecarlo.in/products/men-grey-solid-hooded-full-sleeve-sweatshirt-223061322-1',
#  'https://www.montecarlo.in/products/men-grey-solid-hooded-full-sleeve-sweatshirt-223061301-2',
#  'https://www.montecarlo.in/products/men-grey-solid-hooded-full-sleeve-sweatshirt-2230101553-1',
#  'https://www.montecarlo.in/products/men-grey-solid-hooded-full-sleeve-sweatshirt-2230101549-1',
#  'https://www.montecarlo.in/products/men-blue-solid-round-neck-full-sleeve-sweatshirt-2230101538-7',
# ...

# %%
size_1=[]
size_2=[]
size_3=[]
size_4=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[1]/label')
        size_1.append(description.text)
    except NoSuchElementException :
        size_1.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[2]/label')
        size_2.append(description.text)
    except NoSuchElementException :
        size_2.append('Not present')
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[3]/label')
        size_3.append(description.text)
    except NoSuchElementException :
        size_3.append('Not present')
        
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[4]/label')
        size_4.append(description.text)
    except NoSuchElementException :
        size_4.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte6_size=pd.DataFrame({'Size1':size_1, 'Size2':size_2, 'Size3': size_3, 'Size4':size_4})
monte6_size
# Out:
#            Size1        Size2 Size3  Size4
# 0           36/S  Not present  40/L  42/XL
# 1    Not present         38/M  40/L  42/XL
# 2           36/S         38/M  40/L  42/XL
# 3           36/S         38/M  40/L  42/XL
# 4           36/S         38/M  40/L  42/XL
# ..           ...          ...   ...    ...
# 283         36/S         38/M  40/L  42/XL
# 284         36/S         38/M  40/L  42/XL
# 285         36/S         38/M  40/L  42/XL
# 286         36/S  Not present  40/L  42/XL
# 287         36/S         38/M  40/L  42/XL
#
# [288 rows x 4 columns]

# %%
monte6_size.to_csv('monte5_ocsmaterialoriginreturn_copy.csv')

# %%
# !pip install selenium

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '/html/body/div[7]/div/div/button[2]')
subcategory_analyst.click()

# %%
# Entering Designation in search box-
categorynew_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-active"][4]')
categorynew_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=6
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 288

# %%
style=[]
color=[]
brand=[]
occassion=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/p')
        style.append(description.text)
    except NoSuchElementException :
        style.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[2]/p')
        color.append(description.text)
    except NoSuchElementException :
        color.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[3]/p')
        brand.append(description.text)
    except NoSuchElementException :
        brand.append('Not present')
        
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[7]/p')
        brand.append(description.text)
    except NoSuchElementException :
        brand.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte6_stylecolorbrand=pd.DataFrame({'Style':style, 'Color':color})
monte6_stylecolorbrand
# Out:
#             Style           Color
# 0    2230101550-2           Cream
# 1    2230101550-1           Brown
# 2     223061327-1       Navy Blue
# 3     Not present       Navy Blue
# 4     223061322-1            Grey
# ..            ...             ...
# 283     22MO104-2           Peach
# 284   223061356-2            Blue
# 285   222050721-6          Orange
# 286     22MO101-1            Blue
# 287  2230101551-1  Turquoise Blue
#
# [288 rows x 2 columns]

# %%
# Creating Dataframe-
import pandas as pd
monte6_stylecolor=pd.DataFrame({'Style':style, 'Color':color})
monte6_stylecolor
# Out:
#             Style           Color
# 0    2230101550-2           Cream
# 1    2230101550-1           Brown
# 2     223061327-1       Navy Blue
# 3     Not present       Navy Blue
# 4     223061322-1            Grey
# ..            ...             ...
# 283     22MO104-2           Peach
# 284   223061356-2            Blue
# 285   222050721-6          Orange
# 286     22MO101-1            Blue
# 287  2230101551-1  Turquoise Blue
#
# [288 rows x 2 columns]

# %%
monte6_stylecolor.to_csv('monte6_stylecolor_copy.csv')

# %%
brand=[]
occassion=[]
mrp=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[3]/p')
        brand.append(description.text)
    except NoSuchElementException :
        brand.append('Not present')
        
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[7]/p')
        occassion.append(description.text)
    except NoSuchElementException :
        occassion.append('Not present')
        
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[7]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[12]/p')
        mrp.append(description.text)
    except NoSuchElementException :
        mrp.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte6_brandoccassionmrp=pd.DataFrame({'Brand':brand, 'Occassion':occassion, 'Price':mrp})
monte6_brandoccassionmrp
# Out:
#            Brand    Occassion        Price
# 0    Not present  Not present  Not present
# 1    Not present  Not present  Not present
# 2    Not present  Not present  Not present
# 3    Not present  Not present  Not present
# 4    Not present  Not present  Not present
# ..           ...          ...          ...
# 283  Not present  Not present  Not present
# 284  Not present  Not present  Not present
# 285  Not present  Not present  Not present
# 286  Not present  Not present  Not present
# 287  Not present       Casual  Not present
#
# [288 rows x 3 columns]

# %%
monte6_brandoccassionmrp.to_csv('monte6_brandoccassionmrp_copy.csv')

# %%
material=[]
origin=[]
return_6=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[13]/p')
        material.append(description.text)
    except NoSuchElementException :
        material.append('Not present')
        
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[15]/p')
        origin.append(description.text)
    except NoSuchElementException :
        origin.append('Not present')
        
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[2]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[2]/p')
        return_6.append(description.text)
    except NoSuchElementException :
        return_6.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte6_materialoriginreturn=pd.DataFrame({'Material':material, 'Origin':origin, 'Return':return_6})
monte6_materialoriginreturn
# Out:
#             Material                                             Origin  \
# 0    Polyester Blend                                              India
# 1        Not present                                              India
# 2       Cotton Blend                                              India
# 3        Not present                                              India
# 4       Cotton Blend                                              India
# ..               ...                                                ...
# 283     Machine Wash  Monte Carlo Fashions Limited Unit-2, 231, Indu...
# 284     Cotton Blend                                              India
# 285     Machine Wash  Monte Carlo Fashions Limited Unit-2, 231, Indu...
# 286     Machine Wash  Monte Carlo Fashions Limited Unit-2, 231, Indu...
# 287  Polyester Blend                                              India
#
#                                                 Return
# ...

# %%
monte6_materialoriginreturn.to_csv('monte6_materialoriginreturn_copy.csv')

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[1]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-active"][2]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=3
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 144

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/men-black-printed-regular-fit-lower-223061522-1',
#  'https://www.montecarlo.in/products/men-grey-solid-regular-fit-lowers-2230880732lo-1',
#  'https://www.montecarlo.in/products/men-olive-self-design-regular-fit-lower-223061528-2',
#  'https://www.montecarlo.in/products/men-black-self-design-regular-fit-lower-223061528-1',
#  'https://www.montecarlo.in/products/men-grey-solid-regular-fit-lowers-2230101525-1',
#  'https://www.montecarlo.in/products/men-olive-solid-regular-fit-lowers-2230101525-2',
#  'https://www.montecarlo.in/products/men-teal-blue-printed-regular-fit-lower-223061522-2',
#  'https://www.montecarlo.in/products/monte-carlo-men-olive-regular-fit-lower-37991',
#  'https://www.montecarlo.in/products/men-grey-printed-regular-fit-lowers-223061521-2',
#  'https://www.montecarlo.in/products/men-teal-blue-solid-regular-fit-lower-223061525-1',
#  'https://www.montecarlo.in/products/men-olive-solid-regular-fit-lower-22403609-11',
# ...

# %%
style=[]
price=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/p')
        style.append(description.text)
    except NoSuchElementException :
        style.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[10]/p')
        price.append(description.text)
    except NoSuchElementException :
        price.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte3_styleprice=pd.DataFrame({'Style':style, 'Price':price})
monte3_styleprice
# Out:
#               Style         Price
# 0       223061522-1
# 1    2230880732LO-1
# 2       223061528-2
# 3       223061528-1
# 4      2230101525-1
# ..              ...           ...
# 139                  Rs. 1,845.00
# 140                  Rs. 2,699.00
# 141                  Rs. 1,845.00
# 142                   Not present
# 143                  Rs. 1,845.00
#
# [144 rows x 2 columns]

# %%
monte3_styleprice.to_csv('monte3_styleprice_copy.csv')

# %%
brand=[]
color=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[3]/p')
        brand.append(description.text)
    except NoSuchElementException :
        brand.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[2]/p')
        color.append(description.text)
    except NoSuchElementException :
        color.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte3_brandcolor=pd.DataFrame({'Brand':brand, 'Color':color})
monte3_brandcolor
# Out:
#            Brand        Color
# 0    Monte Carlo  Not present
# 1    Monte Carlo         Grey
# 2    Monte Carlo        Olive
# 3    Monte Carlo        Black
# 4        Rock.it         Grey
# ..           ...          ...
# 139  Not present    Navy Blue
# 140  Monte Carlo  Not present
# 141  Not present    Navy Blue
# 142  Monte Carlo        Olive
# 143  Monte Carlo        Beige
#
# [144 rows x 2 columns]

# %%
monte3_brandcolor.to_csv('monte3_brandcolor_copy.csv')

# %%
# Entering Designation in search box-
home_analyst = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/nav/ol/li[1]/a')
home_analyst.click()

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[2]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-current slick-active"]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=6
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
len(product_url)
# Out:
# 288

# %%
product_url
# Out:
# ['https://www.montecarlo.in/products/women-purple-solid-v-neck-3-4-sleeve-top-1239758tp-701',
#  'https://www.montecarlo.in/products/women-maroon-solid-v-neck-3-4-sleeve-top-1239758tp-214',
#  'https://www.montecarlo.in/products/women-white-solid-v-neck-3-4-sleeve-top-1239758tp-137',
#  'https://www.montecarlo.in/products/women-blue-solid-sceavy-1232792tp-39',
#  'https://www.montecarlo.in/products/women-red-solid-sceavy-1232792tp-212',
#  'https://www.montecarlo.in/products/monte-carlo-women-green-printed-top-38870',
#  'https://www.montecarlo.in/products/monte-carlo-women-sky-blue-printed-top-38869',
#  'https://www.montecarlo.in/products/monte-carlo-women-purple-printed-top-38868',
#  'https://www.montecarlo.in/products/monte-carlo-women-aqua-blue-printed-top-38867',
#  'https://www.montecarlo.in/products/monte-carlo-women-brown-printed-top-38865',
#  'https://www.montecarlo.in/products/monte-carlo-women-navy-blue-plain-top-38539',
# ...

# %%
#Creating Empty List for different attributes-
title_new=[]
start=0
end=6
for page in range(start,end):
    title_tags = driver.find_elements(By.XPATH, '//a[@class="product-item-meta__title"]')
    for i in title_tags:
        title=i.text
        title_new.append(title)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[7]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')

# %%
len(title_new)
# Out:
# 288

# %%
title_new
# Out:
# ['Women Purple Solid V Neck 3/4 Sleeve Top',
#  'Women Maroon Solid V Neck 3/4 Sleeve Top',
#  'Women White Solid V Neck 3/4 Sleeve Top',
#  'Women Blue Solid Sceavy',
#  'Women Red Solid Sceavy',
#  'Women Green Printed Top',
#  'Women Sky Blue Printed Top',
#  'Women Purple Printed Top',
#  'Women Aqua Blue Printed Top',
#  'Women Brown Printed Top',
#  'Women NAvy Blue Plain Top',
#  'Women Yellow Printed Top',
#  'Women Yellow Embroidered Top',
#  'Women White Embroidered Top',
#  'Women Green Printed Top',
#  'Women Blue Printed Top',
#  'Women Blue Printed Top',
#  'Women Green Printed Top',
#  'Women Off White Printed Top',
#  'Women Beige Printed Top',
#  'Women Maroon Plain Top 2 Pc Set',
#  'Women Olive Plain Top',
#  'Women Black Printed Top',
#  'Women NAvy Blue Printed Top',
#  'Women Peach Printed Top',
#  'Women Peach Printed Top',
#  'Women Purple Embroidered Top',
#  'Women Off White Embroidered Top',
#  'Women Peach Embroidered Top',
#  'Women Pink Printed Top',
# ...

# %%
# Creating Dataframe-
import pandas as pd
monte7_title=pd.DataFrame({'Title':title_new})
monte7_title
# Out:
#                                         Title
# 0    Women Purple Solid V Neck 3/4 Sleeve Top
# 1    Women Maroon Solid V Neck 3/4 Sleeve Top
# 2     Women White Solid V Neck 3/4 Sleeve Top
# 3                     Women Blue Solid Sceavy
# 4                      Women Red Solid Sceavy
# ..                                        ...
# 283               Women Off White Printed Top
# 284                 Women Red Self Design Top
# 285               Women Black Self Design Top
# 286                 Women Red Self Design Top
# 287                Women Grey Self Design Top
#
# [288 rows x 1 columns]

# %%
monte7_title.to_csv('monte7_title_copy.csv')

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[2]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-current slick-active"]')
subcategory_analyst.click()

# %%
#Creating Empty List for different attributes-
mrp_new=[]
start=0
end=6
for page in range(start,end):
    mrp_tags = driver.find_elements(By.XPATH, '//span[@class="price price--highlight"]')
    for i in mrp_tags:
        mrp=i.text
        mrp_new.append(mrp)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[7]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')

# %%
len(mrp_new)
# Out:
# 288

# %%
mrp_new
# Out:
# ['Sale price\nRs. 1,083',
#  'Sale price\nRs. 1,083',
#  'Sale price\nRs. 1,083',
#  'Sale price\nRs. 598',
#  'Sale price\nRs. 598',
#  'Sale price\nRs. 774',
#  'Sale price\nRs. 774',
#  'Sale price\nRs. 774',
#  'Sale price\nRs. 774',
#  'Sale price\nRs. 514',
#  'Sale price\nRs. 1,315',
#  'Sale price\nRs. 1,207',
#  'Sale price\nRs. 1,150',
#  'Sale price\nRs. 1,150',
#  'Sale price\nRs. 1,164',
#  'Sale price\nRs. 1,197',
#  'Sale price\nRs. 1,042',
#  'Sale price\nRs. 864',
#  'Sale price\nRs. 644',
#  'Sale price\nRs. 641',
#  'Sale price\nRs. 627',
#  'Sale price\nRs. 1,097',
#  'Sale price\nRs. 1,097',
#  'Sale price\nRs. 1,067',
#  'Sale price\nRs. 1,042',
#  'Sale price\nRs. 774',
#  'Sale price\nRs. 644',
#  'Sale price\nRs. 644',
#  'Sale price\nRs. 774',
#  'Sale price\nRs. 593',
#  'Sale price\nRs. 553',
#  'Sale price\nRs. 1,042',
#  'Sale price\nRs. 1,042',
#  'Sale price\nRs. 777',
#  'Sale price\nRs. 834',
#  'Sale price\nRs. 596',
#  'Sale price\nRs. 582',
# ...

# %%
# Creating Dataframe-
import pandas as pd
monte7_mrp=pd.DataFrame({'Price':mrp})
monte7_mrp
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 3
#       1 # Creating Dataframe-
#       2 import pandas as pd
# ----> 3 monte7_mrp=pd.DataFrame({'Price':mrp})
#       4 monte7_mrp
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# ...

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# Opening the homepage-
driver.get("https://www.montecarlo.in/")

# %%
# Entering Designation in search box-
category_analyst = driver.find_element(By.XPATH, '/html/body/div[2]/store-header/div/div/nav/desktop-navigation/ul/li[2]/a')
category_analyst.click()

# %%
# Entering Designation in search box-
subcategory_analyst = driver.find_element(By.XPATH, '//div[@class="custom-tems slick-slide slick-current slick-active"]')
subcategory_analyst.click()

# %%
#fetching url to open each product
product_url = []
start=0
end=6
for page in range(start,end):
    url = driver.find_elements(By.XPATH, '//a[@class="product-item__aspect-ratio aspect-ratio "]')
    for i in url:
        product_url.append(i.get_attribute('href'))

# %%
#Creating Empty List for different attributes-
mrp_latest=[]
start=0
end=6
for page in range(start,end):
    mrp_tags = driver.find_elements(By.XPATH, '//span[@class="price price--highlight"]')
    for i in mrp_tags:
        mrp=i.text
        mrp_latest.append(mrp)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[7]/section/div[2]/product-facet/div[2]/page-pagination/nav/a[4]')

# %%
len(mrp_latest)
# Out:
# 288

# %%
mrp_latest
# Out:
# ['Sale price\nRs. 1,083',
#  'Sale price\nRs. 1,083',
#  'Sale price\nRs. 1,083',
#  'Sale price\nRs. 598',
#  'Sale price\nRs. 598',
#  'Sale price\nRs. 774',
#  'Sale price\nRs. 774',
#  'Sale price\nRs. 774',
#  'Sale price\nRs. 774',
#  'Sale price\nRs. 514',
#  'Sale price\nRs. 1,315',
#  'Sale price\nRs. 1,207',
#  'Sale price\nRs. 1,150',
#  'Sale price\nRs. 1,150',
#  'Sale price\nRs. 1,164',
#  'Sale price\nRs. 1,197',
#  'Sale price\nRs. 1,042',
#  'Sale price\nRs. 864',
#  'Sale price\nRs. 644',
#  'Sale price\nRs. 641',
#  'Sale price\nRs. 627',
#  'Sale price\nRs. 1,097',
#  'Sale price\nRs. 1,097',
#  'Sale price\nRs. 1,067',
#  'Sale price\nRs. 1,042',
#  'Sale price\nRs. 774',
#  'Sale price\nRs. 644',
#  'Sale price\nRs. 644',
#  'Sale price\nRs. 774',
#  'Sale price\nRs. 593',
#  'Sale price\nRs. 553',
#  'Sale price\nRs. 1,042',
#  'Sale price\nRs. 1,042',
#  'Sale price\nRs. 777',
#  'Sale price\nRs. 834',
#  'Sale price\nRs. 596',
#  'Sale price\nRs. 582',
# ...

# %%
# Creating Dataframe-
import pandas as pd
monte7_mrp=pd.DataFrame({'Price':mrp_latest})
monte7_mrp
# Out:
#                      Price
# 0    Sale price\nRs. 1,083
# 1    Sale price\nRs. 1,083
# 2    Sale price\nRs. 1,083
# 3      Sale price\nRs. 598
# 4      Sale price\nRs. 598
# ..                     ...
# 283    Sale price\nRs. 553
# 284    Sale price\nRs. 877
# 285    Sale price\nRs. 877
# 286    Sale price\nRs. 987
# 287    Sale price\nRs. 877
#
# [288 rows x 1 columns]

# %%
monte7_mrp.to_csv('monte7_mrp_copy.csv')

# %%
size_1=[]
size_2=[]
size_3=[]
size_4=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[1]/label')
        size_1.append(description.text)
    except NoSuchElementException :
        size_1.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[2]/label')
        size_2.append(description.text)
    except NoSuchElementException :
        size_2.append('Not present')
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[3]/label')
        size_3.append(description.text)
    except NoSuchElementException :
        size_3.append('Not present')
        
        

for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/product-variants/div/div[2]/div[4]/label')
        size_4.append(description.text)
    except NoSuchElementException :
        size_4.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte7_size=pd.DataFrame({'Size1':size_1, 'Size2': size_2, 'Size3': size_3, 'Size4':size_4})
monte7_size
# Out:
#            Size1        Size2 Size3        Size4
# 0           34/S         36/M  38/L        40/XL
# 1           34/S  Not present  38/L        40/XL
# 2    Not present         36/M  38/L        40/XL
# 3    Not present         36/M  38/L        40/XL
# 4           34/S  Not present  38/L        40/XL
# ..           ...          ...   ...          ...
# 283         34/S  Not present  38/L        40/XL
# 284         34/S         36/M  38/L        40/XL
# 285  Not present         36/M  38/L  Not present
# 286         34/S         36/M  38/L        40/XL
# 287  Not present  Not present  38/L        40/XL
#
# [288 rows x 4 columns]

# %%
monte7_size.to_csv('monte7_size_copy.csv')

# %%
style=[]
color=[]
brand=[]
occassion=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[1]/p')
        style.append(description.text)
    except NoSuchElementException :
        style.append('Not present')
        
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[2]/p')
        color.append(description.text)
    except NoSuchElementException :
        color.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[3]/p')
        brand.append(description.text)
    except NoSuchElementException :
        brand.append('Not present')
        

        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[7]/p')
        occassion.append(description.text)
    except NoSuchElementException :
        occassion.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte7_stylecolorbrandoccassion=pd.DataFrame({'Style':style, 'Color': color, 'Brand': brand, 'Occassion':occassion})
monte7_stylecolorbrandoccassion
# Out:
#              Style        Color                Brand    Occassion
# 0    1239758TP-701       Purple          Not present  Not present
# 1    1239758TP-214       Maroon          Monte Carlo       Casual
# 2    1239758TP-137        White          Not present       Casual
# 3     1232792TP-39         Blue          Monte Carlo       Casual
# 4    1232792TP-212          Red          Monte Carlo       Casual
# ..             ...          ...                  ...          ...
# 283    223059039-1  Not present          Monte Carlo
# 284    1217888TP-4          Red  MOCA by Monte Carlo
# 285    1217888TP-2  Not present  MOCA by Monte Carlo
# 286    1217894TP-3  Not present  MOCA by Monte Carlo
# 287    1217890TP-1         Blue  MOCA by Monte Carlo
#
# [288 rows x 4 columns]

# %%
monte7_stylecolorbrandoccassion.to_csv('monte7_stylecolorbrandoccassion_copy.csv')

# %%
commodity=[]
material=[]
origin=[]
return_7=[]

# %%
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[8]/p')
        commodity.append(description.text)
    except NoSuchElementException :
        commodity.append('Not present')
        
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[13]/p')
        material.append(description.text)
    except NoSuchElementException :
        material.append('Not present')
        
        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[1]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[1]/div/div/div[15]/p')
        origin.append(description.text)
    except NoSuchElementException :
        origin.append('Not present')
        

        
for i in product_url:
    driver.get(i)          #iterating each and every url to fetch price details
    time.sleep(5) 
    try:
        desc=driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/button[2]')
        desc.click()
        description = driver.find_element(By.XPATH, '/html/body/div[6]/section/div/div[1]/div/div[1]/div[3]/div[2]/p')
        return_7.append(description.text)
    except NoSuchElementException :
        return_7.append('Not present')

# %%
# Creating Dataframe-
import pandas as pd
monte7_commoditymaterialoriginreturn_7=pd.DataFrame({'Commodity':commodity, 'Material': material, 'Origin': origin, 
                                                     'Return':return_7})
monte7_commoditymaterialoriginreturn_7
# Out:
#        Commodity     Material Origin  \
# 0         V Neck   Wool blend  India
# 1         V Neck   Wool blend  India
# 2         V Neck  Not present  India
# 3     Round Neck   Wool blend  India
# 4     Round Neck   Wool blend  India
# ..           ...          ...    ...
# 283          Top  Not present  India
# 284          Top   Wool blend  India
# 285          Top   Wool blend  India
# 286  Not present   Wool blend  India
# 287          Top   Wool blend  India
#
#                                                 Return
# 0    This item is eligible for return within 7 days...
# 1    This item is eligible for return within 7 days...
# 2    This item is eligible for return within 7 days...
# 3    This item is eligible for return within 7 days...
# 4    This item is eligible for return within 7 days...
# ..                                                 ...
# 283  This item is eligible for return within 7 days...
# 284  This item is eligible for return within 7 days...
# ...

# %%
monte7_commoditymaterialoriginreturn_7.to_csv('monte7_commoditymaterialoriginreturn_7_copy.csv')
